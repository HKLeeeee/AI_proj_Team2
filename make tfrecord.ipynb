# %%
import numpy as np
import random
import os
import math

from glob import glob
import pandas as pd
import cv2
from tqdm.auto import tqdm

import tensorflow as tf
# Out:
# 2022-05-10 09:17:37.689534: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
def get_data(data_dir):
    img_path_list = []
    label_list = []
    for case_name in os.listdir(data_dir):
        current_path = os.path.join(data_dir, case_name)
        if os.path.isdir(current_path):
            # get image path
            img_path_list.extend(glob(os.path.join(current_path, 'image', '*.jpg')))
            img_path_list.extend(glob(os.path.join(current_path, 'image', '*.png')))
            
            # get label
            label_df = pd.read_csv(current_path+'/label-'+str(int(case_name[-2:]))+'.csv')
            label_list.extend(label_df['leaf_weight'])
                
    return img_path_list, label_list

def get_test_data(data_dir):
    # get image path
    img_path_list = glob(os.path.join(data_dir, 'image', '*.jpg'))
    img_path_list.extend(glob(os.path.join(data_dir, 'image', '*.png')))
    img_path_list.sort(key=lambda x:int(x.split('/')[-1].split('.')[0]))
    return img_path_list

# %%
all_img_path, all_label = get_data('./data/train')
test_img_path = get_test_data('./data/test')

# %%
all_img_path
# Out:
# ['./data/train/CASE31/image/CASE31_08.jpg',
#  './data/train/CASE31/image/CASE31_04.jpg',
#  './data/train/CASE31/image/CASE31_05.jpg',
#  './data/train/CASE31/image/CASE31_09.jpg',
#  './data/train/CASE31/image/CASE31_01.jpg',
#  './data/train/CASE31/image/CASE31_06.jpg',
#  './data/train/CASE31/image/CASE31_02.jpg',
#  './data/train/CASE31/image/CASE31_03.jpg',
#  './data/train/CASE31/image/CASE31_07.jpg',
#  './data/train/CASE09/image/CASE09_02.jpg',
#  './data/train/CASE09/image/CASE09_06.jpg',
#  './data/train/CASE09/image/CASE09_03.jpg',
#  './data/train/CASE09/image/CASE09_05.jpg',
#  './data/train/CASE09/image/CASE09_01.jpg',
#  './data/train/CASE09/image/CASE09_09.jpg',
#  './data/train/CASE09/image/CASE09_04.jpg',
#  './data/train/CASE09/image/CASE09_08.jpg',
#  './data/train/CASE09/image/CASE09_07.jpg',
#  './data/train/CASE37/image/CASE37_01.png',
#  './data/train/CASE37/image/CASE37_24.png',
#  './data/train/CASE37/image/CASE37_05.png',
#  './data/train/CASE37/image/CASE37_25.png',
#  './data/train/CASE37/image/CASE37_23.png',
#  './data/train/CASE37/image/CASE37_03.png',
#  './data/train/CASE37/image/CASE37_07.png',
#  './data/train/CASE37/image/CASE37_11.png',
#  './data/train/CASE37/image/CASE37_10.png',
#  './data/train/CASE37/image/CASE37_14.png',
#  './data/train/CASE37/image/CASE37_20.png',
#  './data/train/CASE37/image/CASE37_04.png',
#  './data/train/CASE37/image/CASE37_22.png',
#  './data/train/CASE37/image/CASE37_13.png',
#  './data/train/CASE37/image/CASE37_26.png',
#  './data/train/CASE37/image/CASE37_21.png',
#  './data/train/CASE37/image/CASE37_06.png',
#  './data/train/CASE37/image/CASE37_18.png',
#  './data/train/CASE37/image/CASE37_17.png',
#  './data/train/CASE37/image/CASE37_12.png',
#  './data/train/CASE37/image/CASE37_16.png',
#  './data/train/CASE37/image/CASE37_27.png',
#  './data/train/CASE37/image/CASE37_09.png',
#  './data/train/CASE37/image/CASE37_15.png',
#  './data/train/CASE37/image/CASE37_02.png',
#  './data/train/CASE37/image/CASE37_08.png',
#  './data/train/CASE37/image/CASE37_19.png',
#  './data/train/CASE65/image/CASE65_01.png',
#  './data/train/CASE65/image/CASE65_02.png',
#  './data/train/CASE24/image/CASE24_06.png',
#  './data/train/CASE24/image/CASE24_01.png',
#  './data/train/CASE24/image/CASE24_09.png',
#  './data/train/CASE24/image/CASE24_03.png',
#  './data/train/CASE24/image/CASE24_02.png',
#  './data/train/CASE24/image/CASE24_05.png',
#  './data/train/CASE24/image/CASE24_08.png',
#  './data/train/CASE24/image/CASE24_04.png',
#  './data/train/CASE24/image/CASE24_07.png',
#  './data/train/CASE12/image/CASE12_17.png',
#  './data/train/CASE12/image/CASE12_39.png',
#  './data/train/CASE12/image/CASE12_40.png',
#  './data/train/CASE12/image/CASE12_24.png',
#  './data/train/CASE12/image/CASE12_12.png',
#  './data/train/CASE12/image/CASE12_18.png',
#  './data/train/CASE12/image/CASE12_11.png',
#  './data/train/CASE12/image/CASE12_28.png',
#  './data/train/CASE12/image/CASE12_36.png',
#  './data/train/CASE12/image/CASE12_08.png',
#  './data/train/CASE12/image/CASE12_32.png',
#  './data/train/CASE12/image/CASE12_14.png',
#  './data/train/CASE12/image/CASE12_01.png',
#  './data/train/CASE12/image/CASE12_27.png',
#  './data/train/CASE12/image/CASE12_22.png',
#  './data/train/CASE12/image/CASE12_21.png',
#  './data/train/CASE12/image/CASE12_42.png',
#  './data/train/CASE12/image/CASE12_25.png',
#  './data/train/CASE12/image/CASE12_37.png',
#  './data/train/CASE12/image/CASE12_06.png',
#  './data/train/CASE12/image/CASE12_07.png',
#  './data/train/CASE12/image/CASE12_35.png',
#  './data/train/CASE12/image/CASE12_30.png',
#  './data/train/CASE12/image/CASE12_05.png',
#  './data/train/CASE12/image/CASE12_20.png',
#  './data/train/CASE12/image/CASE12_15.png',
#  './data/train/CASE12/image/CASE12_41.png',
#  './data/train/CASE12/image/CASE12_19.png',
#  './data/train/CASE12/image/CASE12_33.png',
#  './data/train/CASE12/image/CASE12_02.png',
#  './data/train/CASE12/image/CASE12_16.png',
#  './data/train/CASE12/image/CASE12_10.png',
#  './data/train/CASE12/image/CASE12_04.png',
#  './data/train/CASE12/image/CASE12_13.png',
#  './data/train/CASE12/image/CASE12_09.png',
#  './data/train/CASE12/image/CASE12_29.png',
#  './data/train/CASE12/image/CASE12_23.png',
#  './data/train/CASE12/image/CASE12_03.png',
#  './data/train/CASE12/image/CASE12_31.png',
#  './data/train/CASE12/image/CASE12_34.png',
#  './data/train/CASE12/image/CASE12_38.png',
#  './data/train/CASE12/image/CASE12_26.png',
#  './data/train/CASE42/image/CASE42_13.png',
#  './data/train/CASE42/image/CASE42_04.png',
#  './data/train/CASE42/image/CASE42_01.png',
#  './data/train/CASE42/image/CASE42_15.png',
#  './data/train/CASE42/image/CASE42_14.png',
#  './data/train/CASE42/image/CASE42_11.png',
#  './data/train/CASE42/image/CASE42_26.png',
#  './data/train/CASE42/image/CASE42_25.png',
#  './data/train/CASE42/image/CASE42_28.png',
#  './data/train/CASE42/image/CASE42_18.png',
#  './data/train/CASE42/image/CASE42_10.png',
#  './data/train/CASE42/image/CASE42_19.png',
#  './data/train/CASE42/image/CASE42_17.png',
#  './data/train/CASE42/image/CASE42_08.png',
#  './data/train/CASE42/image/CASE42_23.png',
#  './data/train/CASE42/image/CASE42_27.png',
#  './data/train/CASE42/image/CASE42_06.png',
#  './data/train/CASE42/image/CASE42_07.png',
#  './data/train/CASE42/image/CASE42_03.png',
#  './data/train/CASE42/image/CASE42_24.png',
#  './data/train/CASE42/image/CASE42_20.png',
#  './data/train/CASE42/image/CASE42_12.png',
#  './data/train/CASE42/image/CASE42_05.png',
#  './data/train/CASE42/image/CASE42_16.png',
#  './data/train/CASE42/image/CASE42_22.png',
#  './data/train/CASE42/image/CASE42_21.png',
#  './data/train/CASE42/image/CASE42_09.png',
#  './data/train/CASE42/image/CASE42_02.png',
#  './data/train/CASE48/image/CASE48_02.png',
#  './data/train/CASE48/image/CASE48_01.png',
#  './data/train/CASE30/image/CASE30_10.jpg',
#  './data/train/CASE30/image/CASE30_01.jpg',
#  './data/train/CASE30/image/CASE30_03.jpg',
#  './data/train/CASE30/image/CASE30_02.jpg',
#  './data/train/CASE30/image/CASE30_09.jpg',
#  './data/train/CASE30/image/CASE30_05.jpg',
#  './data/train/CASE30/image/CASE30_11.jpg',
#  './data/train/CASE30/image/CASE30_07.jpg',
#  './data/train/CASE30/image/CASE30_06.jpg',
#  './data/train/CASE30/image/CASE30_04.jpg',
#  './data/train/CASE30/image/CASE30_08.jpg',
#  './data/train/CASE74/image/CASE74_15.png',
#  './data/train/CASE74/image/CASE74_13.png',
#  './data/train/CASE74/image/CASE74_11.png',
#  './data/train/CASE74/image/CASE74_04.png',
#  './data/train/CASE74/image/CASE74_05.png',
#  './data/train/CASE74/image/CASE74_02.png',
#  './data/train/CASE74/image/CASE74_10.png',
#  './data/train/CASE74/image/CASE74_27.png',
#  './data/train/CASE74/image/CASE74_24.png',
#  './data/train/CASE74/image/CASE74_03.png',
#  './data/train/CASE74/image/CASE74_19.png',
#  './data/train/CASE74/image/CASE74_06.png',
#  './data/train/CASE74/image/CASE74_25.png',
#  './data/train/CASE74/image/CASE74_21.png',
#  './data/train/CASE74/image/CASE74_17.png',
#  './data/train/CASE74/image/CASE74_22.png',
#  './data/train/CASE74/image/CASE74_14.png',
#  './data/train/CASE74/image/CASE74_20.png',
#  './data/train/CASE74/image/CASE74_07.png',
#  './data/train/CASE74/image/CASE74_26.png',
#  './data/train/CASE74/image/CASE74_08.png',
#  './data/train/CASE74/image/CASE74_23.png',
#  './data/train/CASE74/image/CASE74_16.png',
#  './data/train/CASE74/image/CASE74_01.png',
#  './data/train/CASE74/image/CASE74_18.png',
#  './data/train/CASE74/image/CASE74_12.png',
#  './data/train/CASE74/image/CASE74_09.png',
#  './data/train/CASE14/image/CASE14_37.png',
#  './data/train/CASE14/image/CASE14_26.png',
#  './data/train/CASE14/image/CASE14_12.png',
#  './data/train/CASE14/image/CASE14_34.png',
#  './data/train/CASE14/image/CASE14_33.png',
#  './data/train/CASE14/image/CASE14_39.png',
#  './data/train/CASE14/image/CASE14_22.png',
#  './data/train/CASE14/image/CASE14_40.png',
#  './data/train/CASE14/image/CASE14_41.png',
#  './data/train/CASE14/image/CASE14_31.png',
#  './data/train/CASE14/image/CASE14_08.png',
#  './data/train/CASE14/image/CASE14_35.png',
#  './data/train/CASE14/image/CASE14_27.png',
#  './data/train/CASE14/image/CASE14_18.png',
#  './data/train/CASE14/image/CASE14_06.png',
#  './data/train/CASE14/image/CASE14_23.png',
#  './data/train/CASE14/image/CASE14_16.png',
#  './data/train/CASE14/image/CASE14_07.png',
#  './data/train/CASE14/image/CASE14_05.png',
#  './data/train/CASE14/image/CASE14_32.png',
#  './data/train/CASE14/image/CASE14_01.png',
#  './data/train/CASE14/image/CASE14_21.png',
#  './data/train/CASE14/image/CASE14_11.png',
#  './data/train/CASE14/image/CASE14_24.png',
#  './data/train/CASE14/image/CASE14_25.png',
#  './data/train/CASE14/image/CASE14_19.png',
#  './data/train/CASE14/image/CASE14_15.png',
#  './data/train/CASE14/image/CASE14_14.png',
#  './data/train/CASE14/image/CASE14_10.png',
#  './data/train/CASE14/image/CASE14_28.png',
#  './data/train/CASE14/image/CASE14_09.png',
#  './data/train/CASE14/image/CASE14_36.png',
#  './data/train/CASE14/image/CASE14_17.png',
#  './data/train/CASE14/image/CASE14_20.png',
#  './data/train/CASE14/image/CASE14_30.png',
#  './data/train/CASE14/image/CASE14_13.png',
#  './data/train/CASE14/image/CASE14_38.png',
#  './data/train/CASE14/image/CASE14_03.png',
#  './data/train/CASE14/image/CASE14_29.png',
#  './data/train/CASE14/image/CASE14_02.png',
#  './data/train/CASE14/image/CASE14_04.png',
#  './data/train/CASE58/image/CASE58_28.png',
#  './data/train/CASE58/image/CASE58_13.png',
#  './data/train/CASE58/image/CASE58_11.png',
#  './data/train/CASE58/image/CASE58_17.png',
#  './data/train/CASE58/image/CASE58_08.png',
#  './data/train/CASE58/image/CASE58_14.png',
#  './data/train/CASE58/image/CASE58_20.png',
#  './data/train/CASE58/image/CASE58_12.png',
#  './data/train/CASE58/image/CASE58_25.png',
#  './data/train/CASE58/image/CASE58_23.png',
#  './data/train/CASE58/image/CASE58_27.png',
#  './data/train/CASE58/image/CASE58_18.png',
#  './data/train/CASE58/image/CASE58_07.png',
#  './data/train/CASE58/image/CASE58_29.png',
#  './data/train/CASE58/image/CASE58_15.png',
#  './data/train/CASE58/image/CASE58_03.png',
#  './data/train/CASE58/image/CASE58_24.png',
#  './data/train/CASE58/image/CASE58_32.png',
#  './data/train/CASE58/image/CASE58_05.png',
#  './data/train/CASE58/image/CASE58_09.png',
#  './data/train/CASE58/image/CASE58_31.png',
#  './data/train/CASE58/image/CASE58_30.png',
#  './data/train/CASE58/image/CASE58_10.png',
#  './data/train/CASE58/image/CASE58_26.png',
#  './data/train/CASE58/image/CASE58_16.png',
#  './data/train/CASE58/image/CASE58_33.png',
#  './data/train/CASE58/image/CASE58_04.png',
#  './data/train/CASE58/image/CASE58_22.png',
#  './data/train/CASE58/image/CASE58_06.png',
#  './data/train/CASE58/image/CASE58_21.png',
#  './data/train/CASE58/image/CASE58_02.png',
#  './data/train/CASE58/image/CASE58_01.png',
#  './data/train/CASE58/image/CASE58_19.png',
#  './data/train/CASE13/image/CASE13_16.png',
#  './data/train/CASE13/image/CASE13_31.png',
#  './data/train/CASE13/image/CASE13_34.png',
#  './data/train/CASE13/image/CASE13_11.png',
#  './data/train/CASE13/image/CASE13_02.png',
#  './data/train/CASE13/image/CASE13_37.png',
#  './data/train/CASE13/image/CASE13_17.png',
#  './data/train/CASE13/image/CASE13_40.png',
#  './data/train/CASE13/image/CASE13_33.png',
#  './data/train/CASE13/image/CASE13_30.png',
#  './data/train/CASE13/image/CASE13_15.png',
#  './data/train/CASE13/image/CASE13_10.png',
#  './data/train/CASE13/image/CASE13_25.png',
#  './data/train/CASE13/image/CASE13_13.png',
#  './data/train/CASE13/image/CASE13_04.png',
#  './data/train/CASE13/image/CASE13_27.png',
#  './data/train/CASE13/image/CASE13_29.png',
#  './data/train/CASE13/image/CASE13_36.png',
#  './data/train/CASE13/image/CASE13_39.png',
#  './data/train/CASE13/image/CASE13_01.png',
#  './data/train/CASE13/image/CASE13_41.png',
#  './data/train/CASE13/image/CASE13_07.png',
#  './data/train/CASE13/image/CASE13_20.png',
#  './data/train/CASE13/image/CASE13_19.png',
#  './data/train/CASE13/image/CASE13_21.png',
#  './data/train/CASE13/image/CASE13_08.png',
#  './data/train/CASE13/image/CASE13_32.png',
#  './data/train/CASE13/image/CASE13_38.png',
#  './data/train/CASE13/image/CASE13_05.png',
#  './data/train/CASE13/image/CASE13_22.png',
#  './data/train/CASE13/image/CASE13_23.png',
#  './data/train/CASE13/image/CASE13_03.png',
#  './data/train/CASE13/image/CASE13_06.png',
#  './data/train/CASE13/image/CASE13_28.png',
#  './data/train/CASE13/image/CASE13_12.png',
#  './data/train/CASE13/image/CASE13_14.png',
#  './data/train/CASE13/image/CASE13_18.png',
#  './data/train/CASE13/image/CASE13_09.png',
#  './data/train/CASE13/image/CASE13_24.png',
#  './data/train/CASE13/image/CASE13_26.png',
#  './data/train/CASE13/image/CASE13_35.png',
#  './data/train/CASE26/image/CASE26_33.png',
#  './data/train/CASE26/image/CASE26_31.png',
#  './data/train/CASE26/image/CASE26_12.png',
#  './data/train/CASE26/image/CASE26_18.png',
#  './data/train/CASE26/image/CASE26_17.png',
#  './data/train/CASE26/image/CASE26_13.png',
#  './data/train/CASE26/image/CASE26_47.png',
#  './data/train/CASE26/image/CASE26_21.png',
#  './data/train/CASE26/image/CASE26_46.png',
#  './data/train/CASE26/image/CASE26_09.png',
#  './data/train/CASE26/image/CASE26_44.png',
#  './data/train/CASE26/image/CASE26_15.png',
#  './data/train/CASE26/image/CASE26_37.png',
#  './data/train/CASE26/image/CASE26_19.png',
#  './data/train/CASE26/image/CASE26_10.png',
#  './data/train/CASE26/image/CASE26_39.png',
#  './data/train/CASE26/image/CASE26_34.png',
#  './data/train/CASE26/image/CASE26_05.png',
#  './data/train/CASE26/image/CASE26_30.png',
#  './data/train/CASE26/image/CASE26_03.png',
#  './data/train/CASE26/image/CASE26_04.png',
#  './data/train/CASE26/image/CASE26_02.png',
#  './data/train/CASE26/image/CASE26_23.png',
#  './data/train/CASE26/image/CASE26_06.png',
#  './data/train/CASE26/image/CASE26_16.png',
#  './data/train/CASE26/image/CASE26_32.png',
#  './data/train/CASE26/image/CASE26_22.png',
#  './data/train/CASE26/image/CASE26_28.png',
#  './data/train/CASE26/image/CASE26_42.png',
#  './data/train/CASE26/image/CASE26_20.png',
#  './data/train/CASE26/image/CASE26_26.png',
#  './data/train/CASE26/image/CASE26_41.png',
#  './data/train/CASE26/image/CASE26_11.png',
#  './data/train/CASE26/image/CASE26_36.png',
#  './data/train/CASE26/image/CASE26_25.png',
#  './data/train/CASE26/image/CASE26_43.png',
#  './data/train/CASE26/image/CASE26_24.png',
#  './data/train/CASE26/image/CASE26_01.png',
#  './data/train/CASE26/image/CASE26_29.png',
#  './data/train/CASE26/image/CASE26_14.png',
#  './data/train/CASE26/image/CASE26_45.png',
#  './data/train/CASE26/image/CASE26_40.png',
#  './data/train/CASE26/image/CASE26_27.png',
#  './data/train/CASE26/image/CASE26_07.png',
#  './data/train/CASE26/image/CASE26_08.png',
#  './data/train/CASE26/image/CASE26_38.png',
#  './data/train/CASE26/image/CASE26_35.png',
#  './data/train/CASE72/image/CASE72_10.png',
#  './data/train/CASE72/image/CASE72_02.png',
#  './data/train/CASE72/image/CASE72_01.png',
#  './data/train/CASE72/image/CASE72_03.png',
#  './data/train/CASE72/image/CASE72_05.png',
#  './data/train/CASE72/image/CASE72_08.png',
#  './data/train/CASE72/image/CASE72_04.png',
#  './data/train/CASE72/image/CASE72_06.png',
#  './data/train/CASE72/image/CASE72_07.png',
#  './data/train/CASE72/image/CASE72_09.png',
#  './data/train/CASE64/image/CASE64_07.png',
#  './data/train/CASE64/image/CASE64_12.png',
#  './data/train/CASE64/image/CASE64_10.png',
#  './data/train/CASE64/image/CASE64_13.png',
#  './data/train/CASE64/image/CASE64_09.png',
#  './data/train/CASE64/image/CASE64_04.png',
#  './data/train/CASE64/image/CASE64_05.png',
#  './data/train/CASE64/image/CASE64_18.png',
#  './data/train/CASE64/image/CASE64_21.png',
#  './data/train/CASE64/image/CASE64_03.png',
#  './data/train/CASE64/image/CASE64_06.png',
#  './data/train/CASE64/image/CASE64_01.png',
#  './data/train/CASE64/image/CASE64_16.png',
#  './data/train/CASE64/image/CASE64_15.png',
#  './data/train/CASE64/image/CASE64_17.png',
#  './data/train/CASE64/image/CASE64_11.png',
#  './data/train/CASE64/image/CASE64_23.png',
#  './data/train/CASE64/image/CASE64_02.png',
#  './data/train/CASE64/image/CASE64_19.png',
#  './data/train/CASE64/image/CASE64_08.png',
#  './data/train/CASE64/image/CASE64_22.png',
#  './data/train/CASE64/image/CASE64_20.png',
#  './data/train/CASE64/image/CASE64_14.png',
#  './data/train/CASE50/image/CASE50_22.png',
#  './data/train/CASE50/image/CASE50_20.png',
#  './data/train/CASE50/image/CASE50_04.png',
#  './data/train/CASE50/image/CASE50_27.png',
#  './data/train/CASE50/image/CASE50_06.png',
#  './data/train/CASE50/image/CASE50_12.png',
#  './data/train/CASE50/image/CASE50_21.png',
#  './data/train/CASE50/image/CASE50_19.png',
#  './data/train/CASE50/image/CASE50_02.png',
#  './data/train/CASE50/image/CASE50_03.png',
#  './data/train/CASE50/image/CASE50_26.png',
#  './data/train/CASE50/image/CASE50_11.png',
#  './data/train/CASE50/image/CASE50_07.png',
#  './data/train/CASE50/image/CASE50_05.png',
#  './data/train/CASE50/image/CASE50_01.png',
#  './data/train/CASE50/image/CASE50_28.png',
#  './data/train/CASE50/image/CASE50_08.png',
#  './data/train/CASE50/image/CASE50_10.png',
#  './data/train/CASE50/image/CASE50_15.png',
#  './data/train/CASE50/image/CASE50_17.png',
#  './data/train/CASE50/image/CASE50_23.png',
#  './data/train/CASE50/image/CASE50_13.png',
#  './data/train/CASE50/image/CASE50_14.png',
#  './data/train/CASE50/image/CASE50_24.png',
#  './data/train/CASE50/image/CASE50_16.png',
#  './data/train/CASE50/image/CASE50_09.png',
#  './data/train/CASE50/image/CASE50_25.png',
#  './data/train/CASE50/image/CASE50_18.png',
#  './data/train/CASE53/image/CASE53_05.png',
#  './data/train/CASE53/image/CASE53_23.png',
#  './data/train/CASE53/image/CASE53_19.png',
#  './data/train/CASE53/image/CASE53_15.png',
#  './data/train/CASE53/image/CASE53_21.png',
#  './data/train/CASE53/image/CASE53_27.png',
#  './data/train/CASE53/image/CASE53_18.png',
#  './data/train/CASE53/image/CASE53_08.png',
#  './data/train/CASE53/image/CASE53_13.png',
#  './data/train/CASE53/image/CASE53_12.png',
#  './data/train/CASE53/image/CASE53_20.png',
#  './data/train/CASE53/image/CASE53_25.png',
#  './data/train/CASE53/image/CASE53_26.png',
#  './data/train/CASE53/image/CASE53_02.png',
#  './data/train/CASE53/image/CASE53_16.png',
#  './data/train/CASE53/image/CASE53_01.png',
#  './data/train/CASE53/image/CASE53_07.png',
#  './data/train/CASE53/image/CASE53_10.png',
#  './data/train/CASE53/image/CASE53_09.png',
#  './data/train/CASE53/image/CASE53_03.png',
#  './data/train/CASE53/image/CASE53_17.png',
#  './data/train/CASE53/image/CASE53_22.png',
#  './data/train/CASE53/image/CASE53_06.png',
#  './data/train/CASE53/image/CASE53_11.png',
#  './data/train/CASE53/image/CASE53_04.png',
#  './data/train/CASE53/image/CASE53_24.png',
#  './data/train/CASE53/image/CASE53_14.png',
#  './data/train/CASE57/image/CASE57_23.png',
#  './data/train/CASE57/image/CASE57_13.png',
#  './data/train/CASE57/image/CASE57_21.png',
#  './data/train/CASE57/image/CASE57_22.png',
#  './data/train/CASE57/image/CASE57_15.png',
#  './data/train/CASE57/image/CASE57_08.png',
#  './data/train/CASE57/image/CASE57_09.png',
#  './data/train/CASE57/image/CASE57_26.png',
#  './data/train/CASE57/image/CASE57_24.png',
#  './data/train/CASE57/image/CASE57_12.png',
#  './data/train/CASE57/image/CASE57_05.png',
#  './data/train/CASE57/image/CASE57_03.png',
#  './data/train/CASE57/image/CASE57_17.png',
#  './data/train/CASE57/image/CASE57_27.png',
#  './data/train/CASE57/image/CASE57_07.png',
#  './data/train/CASE57/image/CASE57_14.png',
#  './data/train/CASE57/image/CASE57_02.png',
#  './data/train/CASE57/image/CASE57_19.png',
#  './data/train/CASE57/image/CASE57_06.png',
#  './data/train/CASE57/image/CASE57_11.png',
#  './data/train/CASE57/image/CASE57_10.png',
#  './data/train/CASE57/image/CASE57_16.png',
#  './data/train/CASE57/image/CASE57_01.png',
#  './data/train/CASE57/image/CASE57_20.png',
#  './data/train/CASE57/image/CASE57_25.png',
#  './data/train/CASE57/image/CASE57_18.png',
#  './data/train/CASE57/image/CASE57_04.png',
#  './data/train/CASE56/image/CASE56_17.png',
#  './data/train/CASE56/image/CASE56_22.png',
#  './data/train/CASE56/image/CASE56_24.png',
#  './data/train/CASE56/image/CASE56_18.png',
#  './data/train/CASE56/image/CASE56_06.png',
#  './data/train/CASE56/image/CASE56_11.png',
#  './data/train/CASE56/image/CASE56_23.png',
#  './data/train/CASE56/image/CASE56_10.png',
#  './data/train/CASE56/image/CASE56_12.png',
#  './data/train/CASE56/image/CASE56_19.png',
#  './data/train/CASE56/image/CASE56_05.png',
#  './data/train/CASE56/image/CASE56_27.png',
#  './data/train/CASE56/image/CASE56_14.png',
#  './data/train/CASE56/image/CASE56_03.png',
#  './data/train/CASE56/image/CASE56_13.png',
#  './data/train/CASE56/image/CASE56_15.png',
#  './data/train/CASE56/image/CASE56_16.png',
#  './data/train/CASE56/image/CASE56_09.png',
#  './data/train/CASE56/image/CASE56_07.png',
#  './data/train/CASE56/image/CASE56_01.png',
#  './data/train/CASE56/image/CASE56_04.png',
#  './data/train/CASE56/image/CASE56_02.png',
#  './data/train/CASE56/image/CASE56_21.png',
#  './data/train/CASE56/image/CASE56_25.png',
#  './data/train/CASE56/image/CASE56_08.png',
#  './data/train/CASE56/image/CASE56_20.png',
#  './data/train/CASE56/image/CASE56_26.png',
#  './data/train/CASE67/image/CASE67_19.png',
#  './data/train/CASE67/image/CASE67_04.png',
#  './data/train/CASE67/image/CASE67_11.png',
#  './data/train/CASE67/image/CASE67_18.png',
#  './data/train/CASE67/image/CASE67_23.png',
#  './data/train/CASE67/image/CASE67_01.png',
#  './data/train/CASE67/image/CASE67_03.png',
#  './data/train/CASE67/image/CASE67_22.png',
#  './data/train/CASE67/image/CASE67_20.png',
#  './data/train/CASE67/image/CASE67_02.png',
#  './data/train/CASE67/image/CASE67_10.png',
#  './data/train/CASE67/image/CASE67_05.png',
#  './data/train/CASE67/image/CASE67_24.png',
#  './data/train/CASE67/image/CASE67_25.png',
#  './data/train/CASE67/image/CASE67_15.png',
#  './data/train/CASE67/image/CASE67_09.png',
#  './data/train/CASE67/image/CASE67_26.png',
#  './data/train/CASE67/image/CASE67_12.png',
#  './data/train/CASE67/image/CASE67_17.png',
#  './data/train/CASE67/image/CASE67_14.png',
#  './data/train/CASE67/image/CASE67_13.png',
#  './data/train/CASE67/image/CASE67_06.png',
#  './data/train/CASE67/image/CASE67_16.png',
#  './data/train/CASE67/image/CASE67_07.png',
#  './data/train/CASE67/image/CASE67_27.png',
#  './data/train/CASE67/image/CASE67_28.png',
#  './data/train/CASE67/image/CASE67_21.png',
#  './data/train/CASE67/image/CASE67_08.png',
#  './data/train/CASE20/image/CASE20_01.jpg',
#  './data/train/CASE20/image/CASE20_04.jpg',
#  './data/train/CASE20/image/CASE20_05.jpg',
#  './data/train/CASE20/image/CASE20_03.jpg',
#  './data/train/CASE20/image/CASE20_07.jpg',
#  './data/train/CASE20/image/CASE20_12.jpg',
#  './data/train/CASE20/image/CASE20_11.jpg',
#  './data/train/CASE20/image/CASE20_10.jpg',
#  './data/train/CASE20/image/CASE20_09.jpg',
#  './data/train/CASE20/image/CASE20_06.jpg',
#  './data/train/CASE20/image/CASE20_02.jpg',
#  './data/train/CASE20/image/CASE20_08.jpg',
#  './data/train/CASE41/image/CASE41_09.png',
#  './data/train/CASE41/image/CASE41_03.png',
#  './data/train/CASE41/image/CASE41_25.png',
#  './data/train/CASE41/image/CASE41_13.png',
#  './data/train/CASE41/image/CASE41_23.png',
#  './data/train/CASE41/image/CASE41_18.png',
#  './data/train/CASE41/image/CASE41_26.png',
#  './data/train/CASE41/image/CASE41_01.png',
#  './data/train/CASE41/image/CASE41_19.png',
#  './data/train/CASE41/image/CASE41_27.png',
#  './data/train/CASE41/image/CASE41_16.png',
#  './data/train/CASE41/image/CASE41_12.png',
#  './data/train/CASE41/image/CASE41_11.png',
#  './data/train/CASE41/image/CASE41_24.png',
#  './data/train/CASE41/image/CASE41_05.png',
#  './data/train/CASE41/image/CASE41_22.png',
#  './data/train/CASE41/image/CASE41_06.png',
#  './data/train/CASE41/image/CASE41_04.png',
#  './data/train/CASE41/image/CASE41_10.png',
#  './data/train/CASE41/image/CASE41_02.png',
#  './data/train/CASE41/image/CASE41_08.png',
#  './data/train/CASE41/image/CASE41_20.png',
#  './data/train/CASE41/image/CASE41_14.png',
#  './data/train/CASE41/image/CASE41_15.png',
#  './data/train/CASE41/image/CASE41_21.png',
#  './data/train/CASE41/image/CASE41_17.png',
#  './data/train/CASE41/image/CASE41_07.png',
#  './data/train/CASE19/image/CASE19_02.jpg',
#  './data/train/CASE19/image/CASE19_01.jpg',
#  './data/train/CASE19/image/CASE19_03.jpg',
#  './data/train/CASE19/image/CASE19_04.jpg',
#  './data/train/CASE19/image/CASE19_05.jpg',
#  './data/train/CASE73/image/CASE73_18.png',
#  './data/train/CASE73/image/CASE73_02.png',
#  './data/train/CASE73/image/CASE73_11.png',
#  './data/train/CASE73/image/CASE73_26.png',
#  './data/train/CASE73/image/CASE73_05.png',
#  './data/train/CASE73/image/CASE73_25.png',
#  './data/train/CASE73/image/CASE73_27.png',
#  './data/train/CASE73/image/CASE73_09.png',
#  './data/train/CASE73/image/CASE73_17.png',
#  './data/train/CASE73/image/CASE73_30.png',
#  './data/train/CASE73/image/CASE73_21.png',
#  './data/train/CASE73/image/CASE73_04.png',
#  './data/train/CASE73/image/CASE73_03.png',
#  './data/train/CASE73/image/CASE73_01.png',
#  './data/train/CASE73/image/CASE73_08.png',
#  './data/train/CASE73/image/CASE73_32.png',
#  './data/train/CASE73/image/CASE73_23.png',
#  './data/train/CASE73/image/CASE73_31.png',
#  './data/train/CASE73/image/CASE73_19.png',
#  './data/train/CASE73/image/CASE73_15.png',
#  './data/train/CASE73/image/CASE73_16.png',
#  './data/train/CASE73/image/CASE73_13.png',
#  './data/train/CASE73/image/CASE73_24.png',
#  './data/train/CASE73/image/CASE73_33.png',
#  './data/train/CASE73/image/CASE73_10.png',
#  './data/train/CASE73/image/CASE73_20.png',
#  './data/train/CASE73/image/CASE73_14.png',
#  './data/train/CASE73/image/CASE73_29.png',
#  './data/train/CASE73/image/CASE73_22.png',
#  './data/train/CASE73/image/CASE73_07.png',
#  './data/train/CASE73/image/CASE73_06.png',
#  './data/train/CASE73/image/CASE73_34.png',
#  './data/train/CASE73/image/CASE73_12.png',
#  './data/train/CASE73/image/CASE73_28.png',
#  './data/train/CASE27/image/CASE27_04.jpg',
#  './data/train/CASE27/image/CASE27_02.jpg',
#  './data/train/CASE27/image/CASE27_01.jpg',
#  './data/train/CASE27/image/CASE27_03.jpg',
#  './data/train/CASE27/image/CASE27_05.jpg',
#  './data/train/CASE39/image/CASE39_04.png',
#  './data/train/CASE39/image/CASE39_10.png',
#  './data/train/CASE39/image/CASE39_08.png',
#  './data/train/CASE39/image/CASE39_19.png',
#  './data/train/CASE39/image/CASE39_07.png',
#  './data/train/CASE39/image/CASE39_01.png',
#  './data/train/CASE39/image/CASE39_14.png',
#  './data/train/CASE39/image/CASE39_05.png',
#  './data/train/CASE39/image/CASE39_20.png',
#  './data/train/CASE39/image/CASE39_21.png',
#  './data/train/CASE39/image/CASE39_25.png',
#  './data/train/CASE39/image/CASE39_24.png',
#  './data/train/CASE39/image/CASE39_11.png',
#  './data/train/CASE39/image/CASE39_13.png',
#  './data/train/CASE39/image/CASE39_22.png',
#  './data/train/CASE39/image/CASE39_02.png',
#  './data/train/CASE39/image/CASE39_28.png',
#  './data/train/CASE39/image/CASE39_03.png',
#  './data/train/CASE39/image/CASE39_09.png',
#  './data/train/CASE39/image/CASE39_06.png',
#  './data/train/CASE39/image/CASE39_15.png',
#  './data/train/CASE39/image/CASE39_23.png',
#  './data/train/CASE39/image/CASE39_18.png',
#  './data/train/CASE39/image/CASE39_17.png',
#  './data/train/CASE39/image/CASE39_27.png',
#  './data/train/CASE39/image/CASE39_26.png',
#  './data/train/CASE39/image/CASE39_16.png',
#  './data/train/CASE39/image/CASE39_12.png',
#  './data/train/CASE62/image/CASE62_10.png',
#  './data/train/CASE62/image/CASE62_01.png',
#  './data/train/CASE62/image/CASE62_15.png',
#  './data/train/CASE62/image/CASE62_20.png',
#  './data/train/CASE62/image/CASE62_21.png',
#  './data/train/CASE62/image/CASE62_08.png',
#  './data/train/CASE62/image/CASE62_27.png',
#  './data/train/CASE62/image/CASE62_04.png',
#  './data/train/CASE62/image/CASE62_22.png',
#  './data/train/CASE62/image/CASE62_24.png',
#  './data/train/CASE62/image/CASE62_19.png',
#  './data/train/CASE62/image/CASE62_09.png',
#  './data/train/CASE62/image/CASE62_18.png',
#  './data/train/CASE62/image/CASE62_06.png',
#  './data/train/CASE62/image/CASE62_12.png',
#  './data/train/CASE62/image/CASE62_28.png',
#  './data/train/CASE62/image/CASE62_17.png',
#  './data/train/CASE62/image/CASE62_02.png',
#  './data/train/CASE62/image/CASE62_16.png',
#  './data/train/CASE62/image/CASE62_23.png',
#  './data/train/CASE62/image/CASE62_11.png',
#  './data/train/CASE62/image/CASE62_07.png',
#  './data/train/CASE62/image/CASE62_26.png',
#  './data/train/CASE62/image/CASE62_03.png',
#  './data/train/CASE62/image/CASE62_13.png',
#  './data/train/CASE62/image/CASE62_25.png',
#  './data/train/CASE62/image/CASE62_14.png',
#  './data/train/CASE62/image/CASE62_05.png',
#  './data/train/CASE55/image/CASE55_06.png',
#  './data/train/CASE55/image/CASE55_08.png',
#  './data/train/CASE55/image/CASE55_04.png',
#  './data/train/CASE55/image/CASE55_18.png',
#  './data/train/CASE55/image/CASE55_17.png',
#  './data/train/CASE55/image/CASE55_07.png',
#  './data/train/CASE55/image/CASE55_01.png',
#  './data/train/CASE55/image/CASE55_15.png',
#  './data/train/CASE55/image/CASE55_10.png',
#  './data/train/CASE55/image/CASE55_24.png',
#  './data/train/CASE55/image/CASE55_25.png',
#  './data/train/CASE55/image/CASE55_12.png',
#  './data/train/CASE55/image/CASE55_14.png',
#  './data/train/CASE55/image/CASE55_20.png',
#  './data/train/CASE55/image/CASE55_27.png',
#  './data/train/CASE55/image/CASE55_23.png',
#  './data/train/CASE55/image/CASE55_09.png',
#  './data/train/CASE55/image/CASE55_13.png',
#  './data/train/CASE55/image/CASE55_28.png',
#  './data/train/CASE55/image/CASE55_05.png',
#  './data/train/CASE55/image/CASE55_03.png',
#  './data/train/CASE55/image/CASE55_11.png',
#  './data/train/CASE55/image/CASE55_19.png',
#  './data/train/CASE55/image/CASE55_16.png',
#  './data/train/CASE55/image/CASE55_26.png',
#  './data/train/CASE55/image/CASE55_02.png',
#  './data/train/CASE55/image/CASE55_22.png',
#  './data/train/CASE55/image/CASE55_21.png',
#  './data/train/CASE32/image/CASE32_20.png',
#  './data/train/CASE32/image/CASE32_14.png',
#  './data/train/CASE32/image/CASE32_22.png',
#  './data/train/CASE32/image/CASE32_01.png',
#  './data/train/CASE32/image/CASE32_03.png',
#  './data/train/CASE32/image/CASE32_24.png',
#  './data/train/CASE32/image/CASE32_10.png',
#  './data/train/CASE32/image/CASE32_05.png',
#  './data/train/CASE32/image/CASE32_07.png',
#  './data/train/CASE32/image/CASE32_09.png',
#  './data/train/CASE32/image/CASE32_21.png',
#  './data/train/CASE32/image/CASE32_16.png',
#  './data/train/CASE32/image/CASE32_13.png',
#  './data/train/CASE32/image/CASE32_11.png',
#  './data/train/CASE32/image/CASE32_18.png',
#  './data/train/CASE32/image/CASE32_26.png',
#  './data/train/CASE32/image/CASE32_15.png',
#  './data/train/CASE32/image/CASE32_04.png',
#  './data/train/CASE32/image/CASE32_02.png',
#  './data/train/CASE32/image/CASE32_23.png',
#  './data/train/CASE32/image/CASE32_06.png',
#  './data/train/CASE32/image/CASE32_12.png',
#  './data/train/CASE32/image/CASE32_19.png',
#  './data/train/CASE32/image/CASE32_25.png',
#  './data/train/CASE32/image/CASE32_17.png',
#  './data/train/CASE32/image/CASE32_08.png',
#  './data/train/CASE06/image/CASE06_10.jpg',
#  './data/train/CASE06/image/CASE06_01.jpg',
#  './data/train/CASE06/image/CASE06_04.jpg',
#  './data/train/CASE06/image/CASE06_06.jpg',
#  './data/train/CASE06/image/CASE06_07.jpg',
#  './data/train/CASE06/image/CASE06_08.jpg',
#  './data/train/CASE06/image/CASE06_03.jpg',
#  './data/train/CASE06/image/CASE06_02.jpg',
#  './data/train/CASE06/image/CASE06_09.jpg',
#  './data/train/CASE06/image/CASE06_11.jpg',
#  './data/train/CASE06/image/CASE06_05.jpg',
#  './data/train/CASE28/image/CASE28_02.jpg',
#  './data/train/CASE28/image/CASE28_03.jpg',
#  './data/train/CASE28/image/CASE28_04.jpg',
#  './data/train/CASE28/image/CASE28_08.jpg',
#  './data/train/CASE28/image/CASE28_05.jpg',
#  './data/train/CASE28/image/CASE28_10.jpg',
#  './data/train/CASE28/image/CASE28_01.jpg',
#  './data/train/CASE28/image/CASE28_07.jpg',
#  './data/train/CASE28/image/CASE28_06.jpg',
#  './data/train/CASE28/image/CASE28_09.jpg',
#  './data/train/CASE25/image/CASE25_08.png',
#  './data/train/CASE25/image/CASE25_13.png',
#  './data/train/CASE25/image/CASE25_07.png',
#  './data/train/CASE25/image/CASE25_20.png',
#  './data/train/CASE25/image/CASE25_19.png',
#  './data/train/CASE25/image/CASE25_02.png',
#  './data/train/CASE25/image/CASE25_05.png',
#  './data/train/CASE25/image/CASE25_16.png',
#  './data/train/CASE25/image/CASE25_11.png',
#  './data/train/CASE25/image/CASE25_14.png',
#  './data/train/CASE25/image/CASE25_17.png',
#  './data/train/CASE25/image/CASE25_18.png',
#  './data/train/CASE25/image/CASE25_09.png',
#  './data/train/CASE25/image/CASE25_10.png',
#  './data/train/CASE25/image/CASE25_03.png',
#  './data/train/CASE25/image/CASE25_01.png',
#  './data/train/CASE25/image/CASE25_06.png',
#  './data/train/CASE25/image/CASE25_04.png',
#  './data/train/CASE25/image/CASE25_12.png',
#  './data/train/CASE25/image/CASE25_15.png',
#  './data/train/CASE54/image/CASE54_28.png',
#  './data/train/CASE54/image/CASE54_10.png',
#  './data/train/CASE54/image/CASE54_19.png',
#  './data/train/CASE54/image/CASE54_17.png',
#  './data/train/CASE54/image/CASE54_13.png',
#  './data/train/CASE54/image/CASE54_16.png',
#  './data/train/CASE54/image/CASE54_07.png',
#  './data/train/CASE54/image/CASE54_02.png',
#  './data/train/CASE54/image/CASE54_26.png',
#  './data/train/CASE54/image/CASE54_20.png',
#  './data/train/CASE54/image/CASE54_09.png',
#  './data/train/CASE54/image/CASE54_01.png',
#  './data/train/CASE54/image/CASE54_18.png',
#  './data/train/CASE54/image/CASE54_14.png',
#  './data/train/CASE54/image/CASE54_23.png',
#  './data/train/CASE54/image/CASE54_03.png',
#  './data/train/CASE54/image/CASE54_25.png',
#  './data/train/CASE54/image/CASE54_12.png',
#  './data/train/CASE54/image/CASE54_04.png',
#  './data/train/CASE54/image/CASE54_21.png',
#  './data/train/CASE54/image/CASE54_08.png',
#  './data/train/CASE54/image/CASE54_24.png',
#  './data/train/CASE54/image/CASE54_15.png',
#  './data/train/CASE54/image/CASE54_27.png',
#  './data/train/CASE54/image/CASE54_05.png',
#  './data/train/CASE54/image/CASE54_06.png',
#  './data/train/CASE54/image/CASE54_22.png',
#  './data/train/CASE54/image/CASE54_11.png',
#  './data/train/CASE52/image/CASE52_04.png',
#  './data/train/CASE52/image/CASE52_27.png',
#  './data/train/CASE52/image/CASE52_15.png',
#  './data/train/CASE52/image/CASE52_21.png',
#  './data/train/CASE52/image/CASE52_09.png',
#  './data/train/CASE52/image/CASE52_16.png',
#  './data/train/CASE52/image/CASE52_07.png',
#  './data/train/CASE52/image/CASE52_17.png',
#  './data/train/CASE52/image/CASE52_05.png',
#  './data/train/CASE52/image/CASE52_13.png',
#  './data/train/CASE52/image/CASE52_08.png',
#  './data/train/CASE52/image/CASE52_20.png',
#  './data/train/CASE52/image/CASE52_24.png',
#  './data/train/CASE52/image/CASE52_25.png',
#  './data/train/CASE52/image/CASE52_26.png',
#  './data/train/CASE52/image/CASE52_11.png',
#  './data/train/CASE52/image/CASE52_01.png',
#  './data/train/CASE52/image/CASE52_18.png',
#  './data/train/CASE52/image/CASE52_02.png',
#  './data/train/CASE52/image/CASE52_19.png',
#  './data/train/CASE52/image/CASE52_06.png',
#  './data/train/CASE52/image/CASE52_03.png',
#  './data/train/CASE52/image/CASE52_12.png',
#  './data/train/CASE52/image/CASE52_14.png',
#  './data/train/CASE52/image/CASE52_23.png',
#  './data/train/CASE52/image/CASE52_22.png',
#  './data/train/CASE52/image/CASE52_10.png',
#  './data/train/CASE49/image/CASE49_05.png',
#  './data/train/CASE49/image/CASE49_01.png',
#  './data/train/CASE49/image/CASE49_27.png',
#  './data/train/CASE49/image/CASE49_33.png',
#  './data/train/CASE49/image/CASE49_07.png',
#  './data/train/CASE49/image/CASE49_38.png',
#  './data/train/CASE49/image/CASE49_04.png',
#  './data/train/CASE49/image/CASE49_28.png',
#  './data/train/CASE49/image/CASE49_03.png',
#  './data/train/CASE49/image/CASE49_17.png',
#  './data/train/CASE49/image/CASE49_22.png',
#  './data/train/CASE49/image/CASE49_13.png',
#  './data/train/CASE49/image/CASE49_34.png',
#  './data/train/CASE49/image/CASE49_06.png',
#  './data/train/CASE49/image/CASE49_24.png',
#  './data/train/CASE49/image/CASE49_14.png',
#  './data/train/CASE49/image/CASE49_18.png',
#  './data/train/CASE49/image/CASE49_21.png',
#  './data/train/CASE49/image/CASE49_11.png',
#  './data/train/CASE49/image/CASE49_25.png',
#  './data/train/CASE49/image/CASE49_10.png',
#  './data/train/CASE49/image/CASE49_26.png',
#  './data/train/CASE49/image/CASE49_20.png',
#  './data/train/CASE49/image/CASE49_16.png',
#  './data/train/CASE49/image/CASE49_29.png',
#  './data/train/CASE49/image/CASE49_19.png',
#  './data/train/CASE49/image/CASE49_15.png',
#  './data/train/CASE49/image/CASE49_09.png',
#  './data/train/CASE49/image/CASE49_12.png',
#  './data/train/CASE49/image/CASE49_02.png',
#  './data/train/CASE49/image/CASE49_35.png',
#  './data/train/CASE49/image/CASE49_30.png',
#  './data/train/CASE49/image/CASE49_31.png',
#  './data/train/CASE49/image/CASE49_36.png',
#  './data/train/CASE49/image/CASE49_23.png',
#  './data/train/CASE49/image/CASE49_08.png',
#  './data/train/CASE49/image/CASE49_32.png',
#  './data/train/CASE49/image/CASE49_37.png',
#  './data/train/CASE22/image/CASE22_04.jpg',
#  './data/train/CASE22/image/CASE22_05.jpg',
#  './data/train/CASE22/image/CASE22_07.jpg',
#  './data/train/CASE22/image/CASE22_01.jpg',
#  './data/train/CASE22/image/CASE22_11.jpg',
#  './data/train/CASE22/image/CASE22_03.jpg',
#  './data/train/CASE22/image/CASE22_08.jpg',
#  './data/train/CASE22/image/CASE22_10.jpg',
#  './data/train/CASE22/image/CASE22_09.jpg',
#  './data/train/CASE22/image/CASE22_02.jpg',
#  './data/train/CASE22/image/CASE22_06.jpg',
#  './data/train/CASE08/image/CASE08_10.jpg',
#  './data/train/CASE08/image/CASE08_11.jpg',
#  './data/train/CASE08/image/CASE08_01.jpg',
#  './data/train/CASE08/image/CASE08_08.jpg',
#  './data/train/CASE08/image/CASE08_04.jpg',
#  './data/train/CASE08/image/CASE08_03.jpg',
#  './data/train/CASE08/image/CASE08_09.jpg',
#  './data/train/CASE08/image/CASE08_06.jpg',
#  './data/train/CASE08/image/CASE08_07.jpg',
#  './data/train/CASE08/image/CASE08_05.jpg',
#  './data/train/CASE08/image/CASE08_02.jpg',
#  './data/train/CASE70/image/CASE70_11.png',
#  './data/train/CASE70/image/CASE70_10.png',
#  './data/train/CASE70/image/CASE70_06.png',
#  './data/train/CASE70/image/CASE70_18.png',
#  './data/train/CASE70/image/CASE70_23.png',
#  './data/train/CASE70/image/CASE70_14.png',
#  './data/train/CASE70/image/CASE70_16.png',
#  './data/train/CASE70/image/CASE70_15.png',
#  './data/train/CASE70/image/CASE70_24.png',
#  './data/train/CASE70/image/CASE70_20.png',
#  './data/train/CASE70/image/CASE70_07.png',
#  './data/train/CASE70/image/CASE70_13.png',
#  './data/train/CASE70/image/CASE70_09.png',
#  './data/train/CASE70/image/CASE70_04.png',
#  './data/train/CASE70/image/CASE70_01.png',
#  './data/train/CASE70/image/CASE70_08.png',
#  './data/train/CASE70/image/CASE70_17.png',
#  './data/train/CASE70/image/CASE70_21.png',
#  './data/train/CASE70/image/CASE70_12.png',
#  './data/train/CASE70/image/CASE70_22.png',
#  './data/train/CASE70/image/CASE70_02.png',
#  './data/train/CASE70/image/CASE70_05.png',
#  './data/train/CASE70/image/CASE70_03.png',
#  './data/train/CASE70/image/CASE70_19.png',
#  './data/train/CASE36/image/CASE36_09.png',
#  './data/train/CASE36/image/CASE36_19.png',
#  './data/train/CASE36/image/CASE36_12.png',
#  './data/train/CASE36/image/CASE36_23.png',
#  './data/train/CASE36/image/CASE36_16.png',
#  './data/train/CASE36/image/CASE36_13.png',
#  './data/train/CASE36/image/CASE36_25.png',
#  './data/train/CASE36/image/CASE36_20.png',
#  './data/train/CASE36/image/CASE36_15.png',
#  './data/train/CASE36/image/CASE36_18.png',
#  './data/train/CASE36/image/CASE36_06.png',
#  './data/train/CASE36/image/CASE36_27.png',
#  './data/train/CASE36/image/CASE36_24.png',
#  './data/train/CASE36/image/CASE36_07.png',
#  './data/train/CASE36/image/CASE36_05.png',
#  './data/train/CASE36/image/CASE36_22.png',
#  './data/train/CASE36/image/CASE36_03.png',
#  './data/train/CASE36/image/CASE36_26.png',
#  './data/train/CASE36/image/CASE36_21.png',
#  './data/train/CASE36/image/CASE36_10.png',
#  './data/train/CASE36/image/CASE36_17.png',
#  './data/train/CASE36/image/CASE36_01.png',
#  './data/train/CASE36/image/CASE36_08.png',
#  './data/train/CASE36/image/CASE36_14.png',
#  './data/train/CASE36/image/CASE36_02.png',
#  './data/train/CASE36/image/CASE36_04.png',
#  './data/train/CASE36/image/CASE36_11.png',
#  './data/train/CASE07/image/CASE07_03.jpg',
#  './data/train/CASE07/image/CASE07_09.jpg',
#  './data/train/CASE07/image/CASE07_02.jpg',
#  './data/train/CASE07/image/CASE07_01.jpg',
#  './data/train/CASE07/image/CASE07_04.jpg',
#  './data/train/CASE07/image/CASE07_05.jpg',
#  './data/train/CASE07/image/CASE07_07.jpg',
#  './data/train/CASE07/image/CASE07_08.jpg',
#  './data/train/CASE07/image/CASE07_06.jpg',
#  './data/train/CASE47/image/CASE47_11.png',
#  './data/train/CASE47/image/CASE47_07.png',
#  './data/train/CASE47/image/CASE47_09.png',
#  './data/train/CASE47/image/CASE47_01.png',
#  './data/train/CASE47/image/CASE47_04.png',
#  './data/train/CASE47/image/CASE47_08.png',
#  './data/train/CASE47/image/CASE47_02.png',
#  './data/train/CASE47/image/CASE47_06.png',
#  './data/train/CASE47/image/CASE47_03.png',
#  './data/train/CASE47/image/CASE47_05.png',
#  './data/train/CASE47/image/CASE47_10.png',
#  './data/train/CASE29/image/CASE29_06.jpg',
#  './data/train/CASE29/image/CASE29_01.jpg',
#  './data/train/CASE29/image/CASE29_05.jpg',
#  './data/train/CASE29/image/CASE29_07.jpg',
#  './data/train/CASE29/image/CASE29_08.jpg',
#  './data/train/CASE29/image/CASE29_04.jpg',
#  './data/train/CASE29/image/CASE29_02.jpg',
#  './data/train/CASE29/image/CASE29_03.jpg',
#  './data/train/CASE05/image/CASE05_12.png',
#  './data/train/CASE05/image/CASE05_09.png',
#  './data/train/CASE05/image/CASE05_22.png',
#  './data/train/CASE05/image/CASE05_13.png',
#  './data/train/CASE05/image/CASE05_08.png',
#  './data/train/CASE05/image/CASE05_15.png',
#  './data/train/CASE05/image/CASE05_04.png',
#  './data/train/CASE05/image/CASE05_21.png',
#  './data/train/CASE05/image/CASE05_02.png',
#  './data/train/CASE05/image/CASE05_18.png',
#  './data/train/CASE05/image/CASE05_11.png',
#  './data/train/CASE05/image/CASE05_17.png',
#  './data/train/CASE05/image/CASE05_07.png',
#  './data/train/CASE05/image/CASE05_05.png',
#  './data/train/CASE05/image/CASE05_14.png',
#  './data/train/CASE05/image/CASE05_06.png',
#  './data/train/CASE05/image/CASE05_03.png',
#  './data/train/CASE05/image/CASE05_10.png',
#  './data/train/CASE05/image/CASE05_20.png',
#  './data/train/CASE05/image/CASE05_19.png',
#  './data/train/CASE05/image/CASE05_23.png',
#  './data/train/CASE05/image/CASE05_01.png',
#  './data/train/CASE05/image/CASE05_16.png',
#  './data/train/CASE69/image/CASE69_18.png',
#  './data/train/CASE69/image/CASE69_10.png',
#  './data/train/CASE69/image/CASE69_06.png',
#  './data/train/CASE69/image/CASE69_05.png',
#  './data/train/CASE69/image/CASE69_17.png',
#  './data/train/CASE69/image/CASE69_20.png',
#  './data/train/CASE69/image/CASE69_15.png',
#  './data/train/CASE69/image/CASE69_04.png',
#  './data/train/CASE69/image/CASE69_09.png',
#  './data/train/CASE69/image/CASE69_14.png',
#  './data/train/CASE69/image/CASE69_08.png',
#  './data/train/CASE69/image/CASE69_03.png',
#  './data/train/CASE69/image/CASE69_16.png',
#  './data/train/CASE69/image/CASE69_22.png',
#  './data/train/CASE69/image/CASE69_07.png',
#  './data/train/CASE69/image/CASE69_13.png',
#  './data/train/CASE69/image/CASE69_19.png',
#  './data/train/CASE69/image/CASE69_21.png',
#  './data/train/CASE69/image/CASE69_12.png',
#  './data/train/CASE69/image/CASE69_01.png',
#  './data/train/CASE69/image/CASE69_11.png',
#  './data/train/CASE69/image/CASE69_02.png',
#  './data/train/CASE59/image/CASE59_07.png',
#  './data/train/CASE59/image/CASE59_17.png',
#  './data/train/CASE59/image/CASE59_21.png',
#  './data/train/CASE59/image/CASE59_32.png',
#  './data/train/CASE59/image/CASE59_29.png',
#  './data/train/CASE59/image/CASE59_13.png',
#  './data/train/CASE59/image/CASE59_28.png',
#  './data/train/CASE59/image/CASE59_14.png',
#  './data/train/CASE59/image/CASE59_18.png',
#  './data/train/CASE59/image/CASE59_23.png',
#  './data/train/CASE59/image/CASE59_16.png',
#  './data/train/CASE59/image/CASE59_15.png',
#  './data/train/CASE59/image/CASE59_10.png',
#  './data/train/CASE59/image/CASE59_33.png',
#  './data/train/CASE59/image/CASE59_26.png',
#  './data/train/CASE59/image/CASE59_19.png',
#  './data/train/CASE59/image/CASE59_05.png',
#  './data/train/CASE59/image/CASE59_08.png',
#  './data/train/CASE59/image/CASE59_25.png',
#  './data/train/CASE59/image/CASE59_11.png',
#  './data/train/CASE59/image/CASE59_04.png',
#  './data/train/CASE59/image/CASE59_27.png',
#  './data/train/CASE59/image/CASE59_30.png',
#  './data/train/CASE59/image/CASE59_22.png',
#  './data/train/CASE59/image/CASE59_31.png',
#  './data/train/CASE59/image/CASE59_24.png',
#  './data/train/CASE59/image/CASE59_20.png',
#  './data/train/CASE59/image/CASE59_01.png',
#  './data/train/CASE59/image/CASE59_02.png',
#  ...]

# %%
all_label
# Out:
# [171.552,
#  202.0,
#  244.189,
#  287.766,
#  302.834,
#  283.914,
#  295.089,
#  366.397,
#  401.508,
#  232.012,
#  247.298,
#  263.449,
#  300.823,
#  361.841,
#  412.072,
#  425.715,
#  384.333,
#  481.375,
#  0.078,
#  0.807,
#  1.37,
#  1.705,
#  2.697,
#  5.36,
#  6.993,
#  8.88,
#  10.594,
#  13.465,
#  18.122,
#  23.059,
#  32.183,
#  39.392,
#  52.586,
#  70.208,
#  85.923,
#  111.158,
#  141.097,
#  169.117,
#  202.979,
#  253.528,
#  276.781,
#  311.464,
#  337.108,
#  356.505,
#  360.081,
#  274.313,
#  324.452,
#  13.287,
#  16.329,
#  22.746,
#  30.274,
#  40.434,
#  50.631,
#  62.844,
#  79.966,
#  100.101,
#  0.025,
#  0.085,
#  0.118,
#  0.184,
#  0.345,
#  0.745,
#  1.174,
#  1.703,
#  2.345,
#  3.155,
#  4.673,
#  6.407,
#  7.71,
#  10.127,
#  13.664,
#  17.404,
#  20.122,
#  24.857,
#  30.439,
#  31.108,
#  32.219,
#  33.292,
#  34.62,
#  34.896,
#  34.11,
#  34.059,
#  34.981,
#  33.545,
#  33.074,
#  33.005,
#  34.829,
#  40.688,
#  41.236,
#  45.935,
#  49.514,
#  48.564,
#  44.351,
#  43.61,
#  43.051,
#  49.445,
#  45.209,
#  54.305,
#  1.389,
#  1.141,
#  1.679,
#  2.952,
#  4.028,
#  5.039,
#  6.294,
#  7.851,
#  9.367,
#  12.014,
#  14.431,
#  16.38,
#  20.382,
#  23.302,
#  30.619,
#  35.093,
#  40.411,
#  43.244,
#  55.415,
#  69.398,
#  83.918,
#  106.825,
#  127.014,
#  160.211,
#  184.96,
#  232.326,
#  272.065,
#  290.788,
#  234.509,
#  231.219,
#  0.0,
#  0.39,
#  0.856,
#  1.361,
#  1.748,
#  2.249,
#  3.368,
#  5.498,
#  7.606,
#  11.277,
#  14.305,
#  1.406,
#  2.13,
#  2.803,
#  3.321,
#  4.791,
#  6.531,
#  8.36,
#  11.216,
#  14.992,
#  19.122,
#  24.574,
#  32.828,
#  42.638,
#  56.133,
#  73.969,
#  92.697,
#  112.762,
#  138.516,
#  166.882,
#  178.519,
#  187.932,
#  198.023,
#  206.349,
#  211.002,
#  211.497,
#  214.116,
#  214.293,
#  0.064,
#  0.13,
#  0.112,
#  0.186,
#  0.48,
#  0.916,
#  1.402,
#  1.843,
#  2.657,
#  3.694,
#  5.254,
#  6.507,
#  7.841,
#  11.408,
#  15.042,
#  17.422,
#  20.628,
#  26.108,
#  30.5,
#  31.94,
#  33.144,
#  34.862,
#  35.509,
#  35.496,
#  36.463,
#  36.701,
#  36.453,
#  36.607,
#  37.23,
#  37.076,
#  36.12,
#  45.993,
#  45.472,
#  48.1,
#  50.014,
#  48.375,
#  44.659,
#  43.648,
#  45.44,
#  54.657,
#  50.008,
#  0.291,
#  0.875,
#  1.437,
#  1.813,
#  2.483,
#  3.719,
#  4.985,
#  7.0,
#  8.732,
#  10.727,
#  13.95,
#  17.931,
#  23.123,
#  32.079,
#  42.731,
#  53.559,
#  69.067,
#  90.919,
#  115.96,
#  141.866,
#  167.456,
#  183.925,
#  200.585,
#  214.632,
#  222.381,
#  227.741,
#  229.616,
#  227.606,
#  233.216,
#  233.949,
#  237.722,
#  235.496,
#  231.617,
#  0.054,
#  0.094,
#  0.114,
#  0.158,
#  0.398,
#  0.816,
#  1.322,
#  1.764,
#  2.447,
#  3.438,
#  4.845,
#  6.115,
#  7.526,
#  11.148,
#  14.451,
#  17.62,
#  20.535,
#  24.972,
#  30.506,
#  32.046,
#  33.408,
#  34.894,
#  35.414,
#  35.412,
#  35.449,
#  35.835,
#  36.723,
#  35.567,
#  36.409,
#  35.042,
#  35.661,
#  46.389,
#  43.961,
#  47.125,
#  50.563,
#  48.271,
#  44.942,
#  43.354,
#  43.78,
#  55.091,
#  47.719,
#  0.368,
#  1.007,
#  1.553,
#  2.115,
#  2.719,
#  3.356,
#  4.093,
#  5.132,
#  6.736,
#  8.82,
#  11.084,
#  12.978,
#  18.471,
#  25.13,
#  32.179,
#  43.948,
#  57.869,
#  67.104,
#  72.545,
#  76.408,
#  81.113,
#  84.111,
#  86.607,
#  86.497,
#  87.443,
#  86.65,
#  86.594,
#  88.088,
#  87.199,
#  76.068,
#  77.616,
#  75.398,
#  72.517,
#  66.635,
#  59.524,
#  53.517,
#  51.655,
#  48.308,
#  42.6,
#  38.751,
#  35.57,
#  38.381,
#  38.039,
#  33.471,
#  24.074,
#  25.447,
#  33.994,
#  102.457,
#  107.045,
#  106.331,
#  106.434,
#  108.026,
#  81.13,
#  83.402,
#  82.783,
#  81.838,
#  83.503,
#  0.804,
#  1.473,
#  2.013,
#  1.877,
#  3.236,
#  4.001,
#  5.759,
#  7.504,
#  9.409,
#  12.614,
#  17.463,
#  25.164,
#  35.12,
#  44.441,
#  58.898,
#  74.584,
#  96.262,
#  125.066,
#  151.75,
#  176.689,
#  202.012,
#  219.052,
#  230.769,
#  0.152,
#  1.024,
#  0.783,
#  1.086,
#  1.665,
#  2.174,
#  2.637,
#  3.762,
#  4.918,
#  6.367,
#  7.64,
#  8.572,
#  12.48,
#  16.644,
#  21.881,
#  26.947,
#  30.686,
#  35.432,
#  40.723,
#  50.393,
#  60.21,
#  72.274,
#  86.97,
#  100.123,
#  113.281,
#  144.931,
#  164.29,
#  183.74,
#  0.154,
#  1.222,
#  2.185,
#  3.072,
#  5.28,
#  5.839,
#  8.057,
#  11.732,
#  15.739,
#  20.077,
#  27.843,
#  33.923,
#  45.802,
#  57.567,
#  73.138,
#  95.45,
#  118.834,
#  141.675,
#  160.001,
#  170.629,
#  203.625,
#  243.899,
#  266.318,
#  307.49,
#  351.648,
#  361.912,
#  373.203,
#  0.275,
#  1.155,
#  1.162,
#  1.406,
#  1.791,
#  2.05,
#  2.76,
#  3.889,
#  4.674,
#  5.669,
#  7.096,
#  12.138,
#  17.865,
#  23.115,
#  29.282,
#  38.09,
#  50.375,
#  64.794,
#  79.14,
#  88.423,
#  113.179,
#  141.528,
#  143.279,
#  176.769,
#  207.281,
#  241.46,
#  266.695,
#  0.149,
#  0.778,
#  1.0,
#  0.95,
#  1.285,
#  1.472,
#  1.894,
#  2.861,
#  3.374,
#  4.145,
#  4.746,
#  6.731,
#  8.607,
#  18.281,
#  22.311,
#  30.994,
#  38.958,
#  53.014,
#  66.327,
#  72.304,
#  93.784,
#  119.059,
#  131.028,
#  160.933,
#  179.876,
#  219.15,
#  227.165,
#  1.652,
#  2.089,
#  1.986,
#  3.002,
#  3.863,
#  4.91,
#  6.24,
#  7.332,
#  8.806,
#  11.106,
#  13.052,
#  15.382,
#  19.995,
#  23.454,
#  29.242,
#  35.084,
#  41.499,
#  48.152,
#  56.159,
#  69.652,
#  83.924,
#  107.044,
#  127.865,
#  154.809,
#  185.538,
#  231.492,
#  270.296,
#  302.396,
#  1.01,
#  1.399,
#  1.91,
#  2.991,
#  3.811,
#  5.259,
#  6.911,
#  9.561,
#  13.555,
#  18.565,
#  24.119,
#  31.588,
#  0.24,
#  0.61,
#  0.871,
#  1.557,
#  2.391,
#  2.977,
#  4.088,
#  5.977,
#  8.193,
#  11.181,
#  16.232,
#  21.481,
#  27.728,
#  35.671,
#  45.779,
#  60.008,
#  74.575,
#  92.388,
#  112.668,
#  130.217,
#  159.44,
#  199.63,
#  230.42,
#  270.83,
#  298.564,
#  336.041,
#  360.455,
#  0.026,
#  0.29,
#  0.578,
#  0.747,
#  0.621,
#  79.037,
#  43.882,
#  51.265,
#  109.29,
#  151.981,
#  203.851,
#  231.503,
#  253.549,
#  264.121,
#  81.278,
#  106.955,
#  114.172,
#  121.165,
#  73.522,
#  80.074,
#  83.934,
#  89.353,
#  89.938,
#  90.672,
#  91.125,
#  93.852,
#  94.867,
#  89.872,
#  91.174,
#  88.145,
#  89.709,
#  92.417,
#  92.315,
#  89.069,
#  75.478,
#  60.492,
#  40.937,
#  26.718,
#  15.702,
#  0.0,
#  0.148,
#  0.514,
#  0.865,
#  1.252,
#  0.061,
#  0.729,
#  0.843,
#  1.655,
#  2.037,
#  2.564,
#  3.136,
#  4.158,
#  5.176,
#  6.58,
#  8.086,
#  10.397,
#  13.741,
#  18.058,
#  26.419,
#  32.706,
#  40.363,
#  50.034,
#  64.913,
#  82.773,
#  101.224,
#  118.941,
#  140.452,
#  173.307,
#  217.023,
#  254.833,
#  272.898,
#  302.911,
#  1.059,
#  1.634,
#  1.999,
#  2.427,
#  3.371,
#  4.015,
#  4.789,
#  6.183,
#  7.46,
#  9.175,
#  11.405,
#  15.18,
#  17.299,
#  22.003,
#  29.117,
#  34.167,
#  42.386,
#  51.009,
#  63.471,
#  75.222,
#  90.699,
#  103.826,
#  121.073,
#  140.776,
#  169.959,
#  193.448,
#  205.564,
#  203.578,
#  0.618,
#  1.055,
#  1.273,
#  1.89,
#  2.515,
#  3.147,
#  3.985,
#  4.76,
#  5.832,
#  7.212,
#  8.297,
#  11.203,
#  13.761,
#  17.781,
#  23.557,
#  29.042,
#  32.799,
#  39.313,
#  48.334,
#  58.008,
#  70.404,
#  83.589,
#  100.073,
#  119.721,
#  145.874,
#  173.524,
#  186.284,
#  201.571,
#  3.474,
#  4.492,
#  4.916,
#  7.164,
#  9.35,
#  11.129,
#  15.833,
#  19.783,
#  23.522,
#  28.08,
#  36.983,
#  50.006,
#  61.429,
#  75.914,
#  92.34,
#  110.591,
#  135.158,
#  162.196,
#  195.631,
#  223.183,
#  274.062,
#  307.825,
#  354.888,
#  401.315,
#  421.914,
#  461.639,
#  0.118,
#  0.5,
#  0.971,
#  1.371,
#  1.395,
#  1.956,
#  2.283,
#  4.698,
#  7.327,
#  10.241,
#  15.189,
#  2.46,
#  2.89,
#  3.5,
#  4.162,
#  5.096,
#  7.069,
#  9.059,
#  11.866,
#  16.227,
#  23.388,
#  157.091,
#  179.448,
#  201.426,
#  215.627,
#  223.54,
#  230.811,
#  238.371,
#  244.485,
#  248.406,
#  248.822,
#  255.141,
#  255.794,
#  254.067,
#  254.35,
#  251.424,
#  249.873,
#  249.311,
#  250.275,
#  248.163,
#  241.791,
#  0.44,
#  0.715,
#  0.948,
#  1.529,
#  2.12,
#  2.52,
#  3.21,
#  3.85,
#  5.073,
#  5.863,
#  7.296,
#  8.988,
#  11.885,
#  14.457,
#  20.583,
#  25.733,
#  29.37,
#  34.807,
#  42.927,
#  50.596,
#  61.876,
#  75.553,
#  90.425,
#  104.852,
#  120.076,
#  156.819,
#  177.689,
#  187.18,
#  0.037,
#  0.563,
#  1.509,
#  2.185,
#  3.996,
#  4.994,
#  6.304,
#  8.371,
#  12.129,
#  15.238,
#  19.266,
#  27.784,
#  35.639,
#  50.571,
#  61.099,
#  80.258,
#  101.087,
#  118.189,
#  134.438,
#  151.72,
#  176.071,
#  205.099,
#  224.083,
#  267.625,
#  319.349,
#  332.087,
#  364.701,
#  0.059,
#  0.33,
#  1.046,
#  1.768,
#  2.687,
#  4.283,
#  6.28,
#  8.245,
#  10.742,
#  13.162,
#  17.273,
#  21.517,
#  28.062,
#  35.146,
#  41.477,
#  45.842,
#  48.929,
#  47.988,
#  49.721,
#  51.066,
#  50.67,
#  53.516,
#  56.192,
#  57.665,
#  59.518,
#  60.599,
#  61.358,
#  63.529,
#  65.199,
#  66.225,
#  69.165,
#  70.232,
#  68.305,
#  69.554,
#  72.017,
#  73.147,
#  74.549,
#  74.015,
#  0.335,
#  0.839,
#  1.346,
#  0.781,
#  0.358,
#  0.919,
#  1.385,
#  2.462,
#  3.186,
#  4.29,
#  6.484,
#  0.486,
#  0.869,
#  1.273,
#  1.748,
#  2.36,
#  3.329,
#  4.571,
#  6.537,
#  9.419,
#  14.134,
#  19.147,
#  194.275,
#  202.623,
#  240.142,
#  273.045,
#  305.591,
#  317.755,
#  327.612,
#  333.874,
#  336.586,
#  351.26,
#  361.317,
#  364.061,
#  369.557,
#  369.356,
#  370.403,
#  325.288,
#  263.336,
#  227.082,
#  205.831,
#  183.62,
#  156.489,
#  134.076,
#  118.905,
#  102.887,
#  0.0,
#  0.351,
#  0.882,
#  1.049,
#  1.892,
#  2.633,
#  4.176,
#  7.259,
#  8.982,
#  10.825,
#  14.491,
#  18.533,
#  24.864,
#  32.697,
#  42.302,
#  57.233,
#  72.754,
#  91.52,
#  119.261,
#  151.731,
#  176.502,
#  214.4,
#  252.328,
#  284.909,
#  320.89,
#  344.99,
#  352.687,
#  165.769,
#  213.404,
#  262.77,
#  321.295,
#  333.104,
#  429.758,
#  395.947,
#  358.881,
#  426.32,
#  125.765,
#  150.61,
#  180.559,
#  199.059,
#  211.385,
#  220.357,
#  224.515,
#  227.271,
#  229.43,
#  230.316,
#  236.228,
#  247.113,
#  281.176,
#  308.232,
#  326.903,
#  325.804,
#  343.533,
#  385.872,
#  418.81,
#  1.472,
#  1.991,
#  2.658,
#  3.315,
#  4.253,
#  5.318,
#  6.035,
#  6.942,
#  9.218,
#  13.001,
#  16.668,
#  21.961,
#  27.872,
#  35.142,
#  41.602,
#  48.623,
#  58.904,
#  69.522,
#  85.606,
#  94.048,
#  56.841,
#  99.48,
#  82.743,
#  0.951,
#  1.243,
#  1.535,
#  1.924,
#  2.381,
#  3.064,
#  4.12,
#  5.913,
#  7.045,
#  8.571,
#  12.025,
#  15.853,
#  19.756,
#  25.514,
#  33.227,
#  42.639,
#  53.978,
#  65.967,
#  79.018,
#  99.009,
#  126.079,
#  153.766,
#  0.291,
#  0.875,
#  1.437,
#  1.813,
#  2.483,
#  3.719,
#  4.985,
#  7.0,
#  8.732,
#  10.727,
#  13.95,
#  17.931,
#  23.123,
#  32.079,
#  42.731,
#  53.559,
#  69.067,
#  90.919,
#  115.96,
#  141.866,
#  167.456,
#  183.925,
#  200.585,
#  214.632,
#  222.381,
#  227.741,
#  229.616,
#  227.606,
#  233.216,
#  ...]

# %%
def _bytes_feature(value):
    # string / byte 타입을 받아서 byte list를 리턴.
    if isinstance(value, type(tf.constant(0))):
        value = value.numpy() # BytesList won't unpack a string from an EagerTensor.
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _float_feature(value):
    # float / double 타입을 받아서 float list를 리턴
    return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _floatarray_feature(array):
    # float / double 타입을 받아서 float list를 리턴
    return tf.train.Feature(float_list=tf.train.FloatList(value=array))

def _int64_feature(value):
    # bool / enum / int / uint 타입을 받아서 int64 list를 리턴
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

# %%
def to_tfrecords(id_list, label_list, tfrecords_path):
    
    print("Converting 시작 (" + tfrecords_path + ' 파일생성)')
    # GZIP으로 압축한 TFRecord 생성하기 위한 option
    # options = tf.io.TFRecordOptions(compression_type = 'GZIP')
        
    with tf.io.TFRecordWriter(path=tfrecords_path) as writer:
        
        for id_, label_ in tqdm(zip(id_list, label_list), 
                                total=len(id_list), 
                                position=0, 
                                leave=True):
            image_path = id_
            _binary_image = tf.io.read_file(image_path)
            
            if image_path[-3:] == 'jpg' :
                shape = tf.image.decode_jpeg(_binary_image).shape
            else : # png
                shape = tf.image.decode_png(_binary_image).shape
                
            string_set = tf.train.Example(features=tf.train.Features(feature={
                'image/height': _int64_feature(shape[0]),
                'image/width': _int64_feature(shape[1]),
                'image/channel': _int64_feature(shape[2]),
                'image_raw': _bytes_feature(_binary_image),
                'label': _float_feature(label_)                
            }))

            # 만들어진 Example 객체를 binary string으로 변환한 후 파일에 저장
            writer.write(string_set.SerializeToString())

# %%
tfrecords_file_save_path='./data/segmentation/TFRecords/Train_images_label.tfrecords'
to_tfrecords(all_img_path, all_label, tfrecords_file_save_path)
# Out:
# Converting 시작 (./data/segmentation/TFRecords/Train_images_label.tfrecords 파일생성)
# 100%|███████████████████████████████████████| 1592/1592 [01:47<00:00, 14.82it/s]

# %%
def to_tfrecords_test_image(id_list, tfrecords_path):
    
    print("Converting 시작 (" + tfrecords_path + ' 파일생성)')
    # GZIP으로 압축한 TFRecord 생성하기 위한 option
    # options = tf.io.TFRecordOptions(compression_type = 'GZIP')
        
    with tf.io.TFRecordWriter(path=tfrecords_path) as writer:
        
        for id_ in tqdm(id_list, 
                         total=len(id_list), 
                         position=0, 
                         leave=True):
            image_path = id_
            _binary_image = tf.io.read_file(image_path)
            
            if image_path[-3:] == 'jpg' :
                shape = tf.image.decode_jpeg(_binary_image).shape
            else : # png
                shape = tf.image.decode_png(_binary_image).shape
                
            string_set = tf.train.Example(features=tf.train.Features(feature={
                'image/height': _int64_feature(shape[0]),
                'image/width': _int64_feature(shape[1]),
                'image/channel': _int64_feature(shape[2]),
                'image_raw': _bytes_feature(_binary_image)       
            }))
            
            writer.write(string_set.SerializeToString())

# %%
tfrecords_file_save_path='./data/segmentation/TFRecords/Test_images.tfrecords'
to_tfrecords_test_image(all_img_path, tfrecords_file_save_path)
# Out:
# Converting 시작 (./data/segmentation/TFRecords/Test_images.tfrecords 파일생성)
# 100%|███████████████████████████████████████| 1592/1592 [01:47<00:00, 14.77it/s]

# %% [markdown]
# ---
#
# ## Load

# %%
BUFFER_SIZE = 16
IMAGE_SIZE = 320
BATCH_SIZE = 8       
NUM_CLASS = 2
LEARNING_RATE = 5e-5

# %%
def _parse_image_function(example_proto):
    image_feature_description = {
        'image/height': tf.io.FixedLenFeature([], tf.int64),
        'image/width': tf.io.FixedLenFeature([], tf.int64),
        'image/channel': tf.io.FixedLenFeature([], tf.int64),
        'image_raw': tf.io.FixedLenFeature([], tf.string),
        'label': tf.io.FixedLenFeature([], tf.float32)
        }
    return tf.io.parse_single_example(example_proto, image_feature_description)

def _parse_image_function_test(example_proto):
    image_feature_description = {
        'image/height': tf.io.FixedLenFeature([], tf.int64),
        'image/width': tf.io.FixedLenFeature([], tf.int64),
        'image/channel': tf.io.FixedLenFeature([], tf.int64),
        'image_raw': tf.io.FixedLenFeature([], tf.string)
        }
    return tf.io.parse_single_example(example_proto, image_feature_description)

def map_func(target_record):      
    img = target_record['image_raw']
    label = target_record['label']
    img = tf.image.decode_jpeg(img, channels=3)    
    return img, label

def map_func_test(target_record):      
    img = target_record['image_raw']
    img = tf.image.decode_jpeg(img, channels=3)    
    return img

def image_preprocess_func(image, label):
    result_image = image / 255
    result_image = tf.image.resize(result_image, 
                                   (IMAGE_SIZE,IMAGE_SIZE),
                                   antialias=False)   
    return result_image, label


# 만약 multinomial classification이면 one_hot처리도 필요함.
def image_postprocess_func(image, label):
#    onehot_label = tf.one_hot(label, depth=1049)    # binary인 경우 one_hot 사용안함.    
    return image, label


def make_dataset(tfrecords_path, is_train):
    
    dataset = tf.data.TFRecordDataset(tfrecords_path)


    if is_train:
        dataset = dataset.map(_parse_image_function,
                          num_parallel_calls=tf.data.experimental.AUTOTUNE)
        dataset = dataset.map(map_func,
                      num_parallel_calls=tf.data.experimental.AUTOTUNE)
        dataset = dataset.shuffle(BUFFER_SIZE)
    else :
        dataset = dataset.map(_parse_image_function_test,
                             num_parallel_calls=tf.data.experimental.AUTOTUNE)
        dataset = dataset.map(map_func_test,
                      num_parallel_calls=tf.data.experimental.AUTOTUNE)
        
    dataset = dataset.map(image_preprocess_func,
                          num_parallel_calls=tf.data.experimental.AUTOTUNE)

    dataset = dataset.map(image_postprocess_func,
                          num_parallel_calls=tf.data.experimental.AUTOTUNE)

    dataset = dataset.batch(BATCH_SIZE)

    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    
    return dataset

# %%
tfrecords_file_save_path='./data/segmentation/TFRecords/Train_images_label.tfrecords'
train_dataset = make_dataset(tfrecords_file_save_path, True)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function map_func at 0x7f55630113a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function map_func at 0x7f55630113a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
train_dataset
# Out:
# <PrefetchDataset shapes: ((None, 320, 320, 3), (None,)), types: (tf.float32, tf.float32)>

# %%
for ele in train_dataset :
    print(ele)
    break
# Out:
# (<tf.Tensor: shape=(8, 320, 320, 3), dtype=float32, numpy=
# array([[[[0.7339706 , 0.71370095, 0.76705885],
#          [0.72205883, 0.7054167 , 0.7631863 ],
#          [0.72561276, 0.71232843, 0.76875   ],
#          ...,
#          [0.8092402 , 0.7696814 , 0.8129902 ],
#          [0.8165196 , 0.782402  , 0.82553923],
#          [0.8064216 , 0.75661767, 0.8077941 ]],
#
#         [[0.7194363 , 0.7076716 , 0.75041664],
#          [0.72884804, 0.72134805, 0.77176476],
#          [0.7298284 , 0.7298284 , 0.77688724],
#          ...,
#          [0.82053924, 0.78784317, 0.8309804 ],
#          [0.82203436, 0.7788726 , 0.83377457],
#          [0.817549  , 0.77009803, 0.81735295]],
#
#         [[0.7341912 , 0.7185049 , 0.77340686],
#          [0.72352946, 0.7156863 , 0.7705883 ],
#          [0.7286765 , 0.72083336, 0.77524513],
#          ...,
#          [0.8104167 , 0.77904415, 0.83002454],
#          [0.8090686 , 0.76593137, 0.8208333 ],
#          [0.81911767, 0.7759804 , 0.8308824 ]],
#
#         ...,
#
#         [[0.7221814 , 0.71433824, 0.7692402 ],
#          [0.6730392 , 0.6625    , 0.71875   ],
#          [0.6862745 , 0.6791667 , 0.7297794 ],
#          ...,
#          [0.8084559 , 0.7780637 , 0.83639705],
#          [0.8112745 , 0.7681372 , 0.8308823 ],
#          [0.81482846, 0.7716912 , 0.8344363 ]],
#
#         [[0.7012007 , 0.6698282 , 0.7286517 ],
#          [0.68835795, 0.66090703, 0.7236521 ],
#          [0.71323436, 0.6910288 , 0.74593073],
#          ...,
#          [0.80563843, 0.7742659 , 0.8330894 ],
#          [0.80926514, 0.7661279 , 0.82102984],
#          [0.80784315, 0.7647059 , 0.8200004 ]],
#
#         [[0.70669305, 0.67139894, 0.7380656 ],
#          [0.7027952 , 0.6792658 , 0.73416775],
#          [0.6930614 , 0.6852183 , 0.7375716 ],
#          ...,
#          [0.8036286 , 0.77078545, 0.8300992 ],
#          [0.8087486 , 0.7706859 , 0.8317395 ],
#          [0.8060786 , 0.7578441 , 0.82568645]]],
#
#
#        [[[0.6499265 , 0.7595343 , 0.82365197],
#          [0.66061276, 0.7707843 , 0.8352206 ],
#          [0.6670834 , 0.7654412 , 0.84291667],
#          ...,
#          [0.7601471 , 0.8092402 , 0.8907843 ],
#          [0.78149515, 0.8297304 , 0.9028677 ],
#          [0.7749755 , 0.828701  , 0.9059559 ]],
#
#         [[0.67039216, 0.7603922 , 0.83156866],
#          [0.6841177 , 0.7821569 , 0.86058825],
#          [0.689902  , 0.79578435, 0.8625    ],
#          ...,
#          [0.76183826, 0.81188726, 0.88686275],
#          [0.7727941 , 0.8312255 , 0.9122549 ],
#          [0.7775    , 0.82514703, 0.9108333 ]],
#
#         [[0.6824755 , 0.76433825, 0.85      ],
#          [0.66801476, 0.77389705, 0.8405638 ],
#          [0.6564951 , 0.77022064, 0.83296573],
#          ...,
#          [0.77107847, 0.82205886, 0.89656866],
#          [0.7590686 , 0.8218137 , 0.8845588 ],
#          [0.77634805, 0.82732844, 0.90183824]],
#
#         ...,
#
#         [[0.6324755 , 0.73149514, 0.8310049 ],
#          [0.62928927, 0.73125005, 0.8214461 ],
#          [0.62058824, 0.7294118 , 0.8161765 ],
#          ...,
#          [0.76409316, 0.8229167 , 0.8974265 ],
#          [0.77696085, 0.8240197 , 0.9181373 ],
#          [0.7779412 , 0.83676475, 0.9191177 ]],
#
#         [[0.64352936, 0.7378923 , 0.8322798 ],
#          [0.6238484 , 0.7336523 , 0.82776994],
#          [0.6437251 , 0.7447055 , 0.84289145],
#          ...,
#          [0.77318645, 0.82024527, 0.9065198 ],
#          [0.7720834 , 0.819731  , 0.91365236],
#          [0.7664218 , 0.8134806 , 0.9072057 ]],
#
#         [[0.62725663, 0.7153213 , 0.815052  ],
#          [0.6332594 , 0.7301229 , 0.82286763],
#          [0.62233   , 0.72617763, 0.8124284 ],
#          ...,
#          [0.76120055, 0.81186336, 0.90173984],
#          [0.77568555, 0.8176471 , 0.9143133 ],
#          [0.77840674, 0.81284374, 0.9124758 ]]],
#
#
#        [[[0.8179412 , 0.82049024, 0.882451  ],
#          [0.8217402 , 0.81781864, 0.87781864],
#          [0.8192647 , 0.8204167 , 0.8736274 ],
#          ...,
#          [0.8014216 , 0.8195343 , 0.86754906],
#          [0.7837745 , 0.8031863 , 0.8594608 ],
#          [0.77975494, 0.7889706 , 0.8477941 ]],
#
#         [[0.8306128 , 0.82708335, 0.8902206 ],
#          [0.8343873 , 0.8305392 , 0.8932598 ],
#          [0.81125003, 0.80924016, 0.87786764],
#          ...,
#          [0.79610294, 0.8084559 , 0.8670343 ],
#          [0.78882354, 0.80490196, 0.8523529 ],
#          [0.80470586, 0.8170588 , 0.8756863 ]],
#
#         [[0.81397057, 0.8218137 , 0.8806373 ],
#          [0.83125   , 0.82732844, 0.89007354],
#          [0.8204657 , 0.82683825, 0.87928927],
#          ...,
#          [0.78811276, 0.81164217, 0.8734069 ],
#          [0.79558825, 0.8063725 , 0.8651961 ],
#          [0.7991421 , 0.80306375, 0.873652  ]],
#
#         ...,
#
#         [[0.7898284 , 0.8045343 , 0.86531866],
#          [0.78860295, 0.81213236, 0.87487745],
#          [0.80490196, 0.81703436, 0.8835784 ],
#          ...,
#          [0.79509807, 0.8029412 , 0.8539216 ],
#          [0.7985294 , 0.8063725 , 0.857353  ],
#          [0.80894613, 0.8050245 , 0.85992646]],
#
#         [[0.8330385 , 0.8297057 , 0.8844114 ],
#          [0.8008337 , 0.80906934, 0.8673041 ],
#          [0.78620094, 0.80169094, 0.8493386 ],
#          ...,
#          [0.78781873, 0.79664224, 0.8438728 ],
#          [0.81235254, 0.80862725, 0.86313665],
#          [0.80122524, 0.8092156 , 0.8563971 ]],
#
#         [[0.8017418 , 0.8107606 , 0.8788002 ],
#          [0.80088276, 0.8140204 , 0.8687251 ],
#          [0.80186313, 0.80867755, 0.8765939 ],
#          ...,
#          [0.803749  , 0.81159216, 0.858651  ],
#          [0.80284256, 0.81477886, 0.850073  ],
#          [0.7874512 , 0.8031375 , 0.8443632 ]]],
#
#
#        ...,
#
#
#        [[[0.7327696 , 0.82193625, 0.8879412 ],
#          [0.70843136, 0.8143137 , 0.8837255 ],
#          [0.72125   , 0.81088233, 0.8857108 ],
#          ...,
#          [0.8056863 , 0.88036764, 0.9347549 ],
#          [0.83004904, 0.89909315, 0.9567402 ],
#          [0.809951  , 0.87779415, 0.9340686 ]],
#
#         [[0.73284316, 0.8151961 , 0.8897059 ],
#          [0.7192157 , 0.82509804, 0.8917647 ],
#          [0.71002454, 0.8159069 , 0.883848  ],
#          ...,
#          [0.7977941 , 0.8835539 , 0.9384314 ],
#          [0.81262255, 0.8832108 , 0.93066174],
#          [0.8063726 , 0.8771569 , 0.9246079 ]],
#
#         [[0.714951  , 0.82867646, 0.8992647 ],
#          [0.73284316, 0.8387255 , 0.9132353 ],
#          [0.7272059 , 0.8183824 , 0.889951  ],
#          ...,
#          [0.8139706 , 0.8884804 , 0.94730395],
#          [0.8039216 , 0.8784314 , 0.9372549 ],
#          [0.8067402 , 0.88125   , 0.94007355]],
#
#         ...,
#
#         [[0.71605396, 0.8204657 , 0.88713235],
#          [0.7180147 , 0.82389706, 0.89840686],
#          [0.69534314, 0.8090686 , 0.8718137 ],
#          ...,
#          [0.83125   , 0.8822304 , 0.94889706],
#          [0.8306373 , 0.88161767, 0.95612746],
#          [0.8137255 , 0.87647057, 0.93921566]],
#
#         [[0.7105885 , 0.8125493 , 0.8713728 ],
#          [0.69487774, 0.8082107 , 0.87115204],
#          [0.70000005, 0.81355375, 0.875024  ],
#          ...,
#          [0.82453483, 0.8820345 , 0.9565443 ],
#          [0.82647014, 0.8778431 , 0.9523529 ],
#          [0.82647014, 0.8822303 , 0.9473037 ]],
#
#         [[0.7140687 , 0.8160295 , 0.8775989 ],
#          [0.6894366 , 0.79531896, 0.8670829 ],
#          [0.71965617, 0.83338165, 0.89372414],
#          ...,
#          [0.8334054 , 0.88615125, 0.96097964],
#          [0.81931394, 0.87813747, 0.95264727],
#          [0.8337496 , 0.8796327 , 0.948848  ]]],
#
#
#        [[[0.70526963, 0.79355395, 0.86      ],
#          [0.7021814 , 0.7923775 , 0.85786766],
#          [0.70259804, 0.8084804 , 0.8757843 ],
#          ...,
#          [0.76754904, 0.8342157 , 0.90480393],
#          [0.79762256, 0.85625   , 0.9178186 ],
#          [0.7758088 , 0.8435049 , 0.91357845]],
#
#         [[0.70053923, 0.7907353 , 0.8534804 ],
#          [0.71436274, 0.8045588 , 0.87514704],
#          [0.6904657 , 0.79588234, 0.8694608 ],
#          ...,
#          [0.7729167 , 0.8473775 , 0.9127941 ],
#          [0.78840685, 0.8472304 , 0.9217402 ],
#          [0.76463234, 0.831299  , 0.9044363 ]],
#
#         [[0.68713236, 0.7930147 , 0.85968137],
#          [0.7022059 , 0.80808824, 0.8747549 ],
#          [0.6854167 , 0.79129905, 0.86580884],
#          ...,
#          [0.7800245 , 0.8535539 , 0.91973037],
#          [0.7868873 , 0.85355395, 0.91629905],
#          [0.79375005, 0.8525735 , 0.9270834 ]],
#
#         ...,
#
#         [[0.6676471 , 0.7610294 , 0.85514706],
#          [0.67561275, 0.77953434, 0.8550245 ],
#          [0.66654414, 0.7810049 , 0.85159314],
#          ...,
#          [0.7866422 , 0.85330886, 0.9238971 ],
#          [0.7875    , 0.84632355, 0.92083335],
#          [0.78333336, 0.8421569 , 0.9166667 ]],
#
#         [[0.67009854, 0.763358  , 0.85122573],
#          [0.6765201 , 0.77397054, 0.85951   ],
#          [0.6759068 , 0.78926426, 0.8604413 ],
#          ...,
#          [0.7942153 , 0.86186236, 0.9315679 ],
#          [0.7925985 , 0.8397309 , 0.92598087],
#          [0.78990215, 0.8488729 , 0.93075967]],
#
#         [[0.68443704, 0.77835745, 0.8660049 ],
#          [0.6434587 , 0.74169326, 0.83358085],
#          [0.6285291 , 0.7500977 , 0.8234318 ],
#          ...,
#          [0.786961  , 0.8501963 , 0.9132846 ],
#          [0.79982746, 0.8429647 , 0.92414194],
#          [0.80223006, 0.8521561 , 0.9374749 ]]],
#
#
#        [[[0.9464706 , 0.8927451 , 0.9621569 ],
#          [0.9433578 , 0.89683825, 0.9612745 ],
#          [0.9492157 , 0.8958333 , 0.9676225 ],
#          ...,
#          [0.95502454, 0.90132356, 0.9679902 ],
#          [0.95365196, 0.90044117, 0.96710783],
#          [0.9556127 , 0.89953434, 0.97267157]],
#
#         [[0.9466176 , 0.8956372 , 0.96622545],
#          [0.94311273, 0.8999755 , 0.96664214],
#          [0.9420588 , 0.8897549 , 0.9610049 ],
#          ...,
#          [0.9490686 , 0.8915441 , 0.9653676 ],
#          [0.94504905, 0.89406866, 0.9646569 ],
#          [0.9540196 , 0.8882108 , 0.97289217]],
#
#         [[0.9487745 , 0.8977941 , 0.96838236],
#          [0.9481617 , 0.9050245 , 0.9677696 ],
#          [0.9522059 , 0.9012255 , 0.97181374],
#          ...,
#          [0.9569853 , 0.9060049 , 0.97267157],
#          [0.96004903, 0.9051471 , 0.97181374],
#          [0.95759803, 0.8987745 , 0.9732843 ]],
#
#         ...,
#
#         [[0.96004903, 0.9012255 , 0.9757353 ],
#          [0.9564951 , 0.9055147 , 0.97610295],
#          [0.9433824 , 0.89240193, 0.95955884],
#          ...,
#          [0.964951  , 0.9139706 , 0.99240196],
#          [0.96654415, 0.9155637 , 0.9939951 ],
#          [0.9637255 , 0.9127451 , 0.9911765 ]],
#
#         [[0.94237816, 0.8831621 , 0.9574756 ],
#          [0.94946074, 0.8910298 , 0.9653433 ],
#          [0.9581366 , 0.90848005, 0.97840637],
#          ...,
#          [0.95701   , 0.9060296 , 0.9831861 ],
#          [0.96419114, 0.91325986, 0.9912741 ],
#          [0.96718144, 0.91992635, 0.9983577 ]],
#
#         [[0.94446087, 0.888186  , 0.9575985 ],
#          [0.93774605, 0.8895115 , 0.9573539 ],
#          [0.9396329 , 0.89649564, 0.9631623 ],
#          ...,
#          [0.9674261 , 0.91198564, 0.989264  ],
#          [0.9663718 , 0.9102941 , 0.98583364],
#          [0.96556395, 0.91458356, 0.9842161 ]]]], dtype=float32)>, <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([361.841, 425.715, 283.914, 232.012, 263.449, 481.375, 300.823,
#          1.37 ], dtype=float32)>)

# %% [markdown]
# # Pretrain model

# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm.auto import tqdm
import cv2

import efficientnet
import efficientnet.tfkeras as efn

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D, Input
import tensorflow.keras as keras
from tensorflow.data import Dataset

import tensorflow_addons as tfa
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# /home/ubuntu/anaconda3/envs/machine/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.6.0 and strictly below 2.9.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.4.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
base_model = efn.EfficientNetB4(
    weights='imagenet',
    include_top = False,
    input_shape = (IMAGE_SIZE,IMAGE_SIZE) + (3,)
)
base_model.summary()
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b4_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 71892992/71892840 [==============================] - 6s 0us/step
# Model: "efficientnet-b4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 160, 160, 48) 1296        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 160, 160, 48) 192         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 160, 160, 48) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 160, 160, 48) 432         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 160, 160, 48) 192         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 160, 160, 48) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 48)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 48)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 12)     588         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 48)     624         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 160, 160, 48) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 160, 160, 24) 1152        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 160, 160, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 160, 160, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 160, 160, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 160, 160, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 160, 160, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 160, 160, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 160, 160, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (FixedDropout)     (None, 160, 160, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 160, 160, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 160, 160, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 160, 160, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 160, 160, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 80, 80, 144)  1296        block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 80, 80, 144)  576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 80, 80, 144)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 80, 80, 144)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 80, 80, 32)   4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 80, 80, 32)   128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 80, 80, 192)  6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 80, 80, 192)  768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 80, 80, 192)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 80, 80, 192)  1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 80, 80, 192)  768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 80, 80, 192)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 80, 80, 192)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 80, 80, 32)   6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 80, 80, 32)   128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (FixedDropout)     (None, 80, 80, 32)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 80, 80, 32)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 80, 80, 192)  6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 80, 80, 192)  768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 80, 80, 192)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 80, 80, 192)  1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 80, 80, 192)  768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 80, 80, 192)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 80, 80, 192)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 80, 80, 32)   6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 80, 80, 32)   128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (FixedDropout)     (None, 80, 80, 32)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 80, 80, 32)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 80, 80, 192)  6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 80, 80, 192)  768         block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 80, 80, 192)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 80, 80, 192)  1728        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 80, 80, 192)  768         block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 80, 80, 192)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 192)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 80, 80, 192)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 80, 80, 32)   6144        block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 80, 80, 32)   128         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (FixedDropout)     (None, 80, 80, 32)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 80, 80, 32)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 80, 80, 192)  6144        block2d_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 80, 80, 192)  768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 80, 80, 192)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 40, 40, 192)  4800        block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 40, 40, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 40, 40, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 40, 40, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 40, 40, 56)   10752       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 40, 40, 56)   224         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 40, 40, 336)  18816       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 40, 40, 336)  1344        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 40, 40, 336)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 40, 40, 336)  8400        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 40, 40, 336)  1344        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 40, 40, 336)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 336)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 40, 40, 336)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 40, 40, 56)   18816       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 40, 40, 56)   224         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (FixedDropout)     (None, 40, 40, 56)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 40, 40, 56)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 40, 40, 336)  18816       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 40, 40, 336)  1344        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 40, 40, 336)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 40, 40, 336)  8400        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 40, 40, 336)  1344        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 40, 40, 336)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 336)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 40, 40, 336)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 40, 40, 56)   18816       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 40, 40, 56)   224         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (FixedDropout)     (None, 40, 40, 56)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 40, 40, 56)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 40, 40, 336)  18816       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 40, 40, 336)  1344        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 40, 40, 336)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 40, 40, 336)  8400        block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 40, 40, 336)  1344        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 40, 40, 336)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 336)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 40, 40, 336)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 40, 40, 56)   18816       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 40, 40, 56)   224         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (FixedDropout)     (None, 40, 40, 56)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 40, 40, 56)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 40, 40, 336)  18816       block3d_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 40, 40, 336)  1344        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 40, 40, 336)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 20, 20, 336)  3024        block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 20, 20, 336)  1344        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 20, 20, 336)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 336)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 336)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 20, 20, 336)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 20, 20, 112)  37632       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 20, 20, 112)  448         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 20, 20, 672)  75264       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 20, 20, 672)  2688        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 20, 20, 672)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 20, 20, 672)  6048        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 20, 20, 672)  2688        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 20, 20, 672)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 672)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 20, 20, 672)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 20, 20, 112)  75264       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 20, 20, 112)  448         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (FixedDropout)     (None, 20, 20, 112)  0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 20, 20, 112)  0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 20, 20, 672)  75264       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 20, 20, 672)  2688        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 20, 20, 672)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 20, 20, 672)  6048        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 20, 20, 672)  2688        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 20, 20, 672)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 672)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 20, 20, 672)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 20, 20, 112)  75264       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 20, 20, 112)  448         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (FixedDropout)     (None, 20, 20, 112)  0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 20, 20, 112)  0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 20, 20, 672)  75264       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 20, 20, 672)  2688        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 20, 20, 672)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 20, 20, 672)  6048        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 20, 20, 672)  2688        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 20, 20, 672)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 672)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 20, 20, 672)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 20, 20, 112)  75264       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 20, 20, 112)  448         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (FixedDropout)     (None, 20, 20, 112)  0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 20, 20, 112)  0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, 20, 20, 672)  75264       block4d_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, 20, 20, 672)  2688        block4e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, 20, 20, 672)  0           block4e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, 20, 20, 672)  6048        block4e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, 20, 20, 672)  2688        block4e_dwconv[0][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, 20, 20, 672)  0           block4e_bn[0][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 672)          0           block4e_activation[0][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, 20, 20, 672)  0           block4e_activation[0][0]
#                                                                  block4e_se_expand[0][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, 20, 20, 112)  75264       block4e_se_excite[0][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, 20, 20, 112)  448         block4e_project_conv[0][0]
# __________________________________________________________________________________________________
# block4e_drop (FixedDropout)     (None, 20, 20, 112)  0           block4e_project_bn[0][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, 20, 20, 112)  0           block4e_drop[0][0]
#                                                                  block4d_add[0][0]
# __________________________________________________________________________________________________
# block4f_expand_conv (Conv2D)    (None, 20, 20, 672)  75264       block4e_add[0][0]
# __________________________________________________________________________________________________
# block4f_expand_bn (BatchNormali (None, 20, 20, 672)  2688        block4f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4f_expand_activation (Acti (None, 20, 20, 672)  0           block4f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4f_dwconv (DepthwiseConv2D (None, 20, 20, 672)  6048        block4f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4f_bn (BatchNormalization) (None, 20, 20, 672)  2688        block4f_dwconv[0][0]
# __________________________________________________________________________________________________
# block4f_activation (Activation) (None, 20, 20, 672)  0           block4f_bn[0][0]
# __________________________________________________________________________________________________
# block4f_se_squeeze (GlobalAvera (None, 672)          0           block4f_activation[0][0]
# __________________________________________________________________________________________________
# block4f_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4f_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4f_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4f_se_excite (Multiply)    (None, 20, 20, 672)  0           block4f_activation[0][0]
#                                                                  block4f_se_expand[0][0]
# __________________________________________________________________________________________________
# ...
# block6f_expand_bn (BatchNormali (None, 10, 10, 1632) 6528        block6f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6f_expand_activation (Acti (None, 10, 10, 1632) 0           block6f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6f_dwconv (DepthwiseConv2D (None, 10, 10, 1632) 40800       block6f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6f_bn (BatchNormalization) (None, 10, 10, 1632) 6528        block6f_dwconv[0][0]
# __________________________________________________________________________________________________
# block6f_activation (Activation) (None, 10, 10, 1632) 0           block6f_bn[0][0]
# __________________________________________________________________________________________________
# block6f_se_squeeze (GlobalAvera (None, 1632)         0           block6f_activation[0][0]
# __________________________________________________________________________________________________
# block6f_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6f_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6f_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6f_se_excite (Multiply)    (None, 10, 10, 1632) 0           block6f_activation[0][0]
#                                                                  block6f_se_expand[0][0]
# __________________________________________________________________________________________________
# block6f_project_conv (Conv2D)   (None, 10, 10, 272)  443904      block6f_se_excite[0][0]
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, 10, 10, 272)  1088        block6f_project_conv[0][0]
# __________________________________________________________________________________________________
# block6f_drop (FixedDropout)     (None, 10, 10, 272)  0           block6f_project_bn[0][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, 10, 10, 272)  0           block6f_drop[0][0]
#                                                                  block6e_add[0][0]
# __________________________________________________________________________________________________
# block6g_expand_conv (Conv2D)    (None, 10, 10, 1632) 443904      block6f_add[0][0]
# __________________________________________________________________________________________________
# block6g_expand_bn (BatchNormali (None, 10, 10, 1632) 6528        block6g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6g_expand_activation (Acti (None, 10, 10, 1632) 0           block6g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6g_dwconv (DepthwiseConv2D (None, 10, 10, 1632) 40800       block6g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6g_bn (BatchNormalization) (None, 10, 10, 1632) 6528        block6g_dwconv[0][0]
# __________________________________________________________________________________________________
# block6g_activation (Activation) (None, 10, 10, 1632) 0           block6g_bn[0][0]
# __________________________________________________________________________________________________
# block6g_se_squeeze (GlobalAvera (None, 1632)         0           block6g_activation[0][0]
# __________________________________________________________________________________________________
# block6g_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6g_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6g_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6g_se_excite (Multiply)    (None, 10, 10, 1632) 0           block6g_activation[0][0]
#                                                                  block6g_se_expand[0][0]
# __________________________________________________________________________________________________
# block6g_project_conv (Conv2D)   (None, 10, 10, 272)  443904      block6g_se_excite[0][0]
# __________________________________________________________________________________________________
# block6g_project_bn (BatchNormal (None, 10, 10, 272)  1088        block6g_project_conv[0][0]
# __________________________________________________________________________________________________
# block6g_drop (FixedDropout)     (None, 10, 10, 272)  0           block6g_project_bn[0][0]
# __________________________________________________________________________________________________
# block6g_add (Add)               (None, 10, 10, 272)  0           block6g_drop[0][0]
#                                                                  block6f_add[0][0]
# __________________________________________________________________________________________________
# block6h_expand_conv (Conv2D)    (None, 10, 10, 1632) 443904      block6g_add[0][0]
# __________________________________________________________________________________________________
# block6h_expand_bn (BatchNormali (None, 10, 10, 1632) 6528        block6h_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6h_expand_activation (Acti (None, 10, 10, 1632) 0           block6h_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6h_dwconv (DepthwiseConv2D (None, 10, 10, 1632) 40800       block6h_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6h_bn (BatchNormalization) (None, 10, 10, 1632) 6528        block6h_dwconv[0][0]
# __________________________________________________________________________________________________
# block6h_activation (Activation) (None, 10, 10, 1632) 0           block6h_bn[0][0]
# __________________________________________________________________________________________________
# block6h_se_squeeze (GlobalAvera (None, 1632)         0           block6h_activation[0][0]
# __________________________________________________________________________________________________
# block6h_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6h_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6h_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6h_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6h_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6h_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6h_se_excite (Multiply)    (None, 10, 10, 1632) 0           block6h_activation[0][0]
#                                                                  block6h_se_expand[0][0]
# __________________________________________________________________________________________________
# block6h_project_conv (Conv2D)   (None, 10, 10, 272)  443904      block6h_se_excite[0][0]
# __________________________________________________________________________________________________
# block6h_project_bn (BatchNormal (None, 10, 10, 272)  1088        block6h_project_conv[0][0]
# __________________________________________________________________________________________________
# block6h_drop (FixedDropout)     (None, 10, 10, 272)  0           block6h_project_bn[0][0]
# __________________________________________________________________________________________________
# block6h_add (Add)               (None, 10, 10, 272)  0           block6h_drop[0][0]
#                                                                  block6g_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 10, 10, 1632) 443904      block6h_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 10, 10, 1632) 6528        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 10, 10, 1632) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 10, 10, 1632) 14688       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 10, 10, 1632) 6528        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 10, 10, 1632) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1632)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 10, 10, 1632) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 10, 10, 448)  731136      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 10, 10, 448)  1792        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 10, 10, 2688) 1204224     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 10, 10, 2688) 10752       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 10, 10, 2688) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 10, 10, 2688) 24192       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 10, 10, 2688) 10752       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 10, 10, 2688) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2688)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2688)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 112)    301168      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2688)   303744      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 10, 10, 2688) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 10, 10, 448)  1204224     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 10, 10, 448)  1792        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (FixedDropout)     (None, 10, 10, 448)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 10, 10, 448)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 10, 10, 1792) 802816      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 10, 10, 1792) 7168        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 10, 10, 1792) 0           top_bn[0][0]
# ==================================================================================================
# Total params: 17,673,816
# Trainable params: 17,548,616
# Non-trainable params: 125,200
# __________________________________________________________________________________________________

# %%
base_model.trainable = False
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D()) # Flatten??
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# # Early Stopping
# es = EarlyStopping(monitor='val_loss',
#                    mode='auto',
#                    patience=5,
#                    verbose=1)

# # Checkpoint
# model_checkpoint = './{epoch:06d}-{val_acc:0.6f}-{acc:0.6f}.ckpt'

# checkpointer = ModelCheckpoint(
#     filepath=model_checkpoint,
#     verbose=1,
#     period=2,
#     save_best_weights=True,
#     mode='auto',
#     monitor='val_acc'
# )

model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
              loss='mse',
              metrics=['acc'])


EPOCHS = 10
STEPS_PER_EPOCH = 1592 // BATCH_SIZE
# VAL_STEPS = len(vali_img_path) // BATCH_SIZE

# %%
history = model.fit(train_dataset, epochs=EPOCHS,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    #validation_data=valid_dataset,
                    #validation_steps = VAL_STEPS,
                    #callbacks=[es, checkpointer],
                    verbose=1)

model.save('./pretrained_model.h5')
# Out:
# Epoch 1/10
# 2022-05-10 10:08:18.141858: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 199/199 [==============================] - 97s 467ms/step - loss: 16173.4619 - acc: 6.2814e-04
# Epoch 2/10
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1990 batches). You may need to use the repeat() function when building your dataset.
# 199/199 [==============================] - 0s 86us/step - loss: 16173.4619 - acc: 6.2814e-04
