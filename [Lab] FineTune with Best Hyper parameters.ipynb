# %% [markdown]
# # Prepare

# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm.auto import tqdm
import cv2

# from tensorflow.keras.applications import Densnet
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D, Input
import tensorflow.keras as keras
from tensorflow.data import Dataset

from tensorflow.keras.optimizers import Adam, RMSprop, Nadam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from itertools import product
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.applications import *
# Out:
# 2022-05-17 14:29:09.717679: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# # Data Load

# %%
## 경로 설정
small_train_images_path = './data/PREPROCESSING-TRAIN'
small_test_images_path = './data/PREPROCESSING-TEST'
data_path = './data'

train_images_name = sorted(os.listdir(small_train_images_path))
train_images_path = \
[os.path.join(small_train_images_path, name) for name in train_images_name]

test_images_name = sorted(os.listdir(small_test_images_path))
test_images_path = \
[os.path.join(small_test_images_path, name) for name in test_images_name]

label_dfs = []
case_names = sorted(os.listdir('./data/train'))

for case in case_names :
    label_path = data_path+'/train/'+case+'/label-{}.csv'.format(str(int(case[-2:])))
    df = pd.read_csv(label_path)
    label_dfs.append(df)
    
label_df = pd.concat(label_dfs, axis=0)
label_df.to_csv('./data/labels.csv', index=False)

label_df.set_index('img_name', inplace=True)

label_df['img_path'] = train_images_path

shuffled_df = label_df.sample(frac=1)

# %% [markdown]
# # Data Generator

# %%
# Train : Validation = 0.8 : 0.2 Split
train_len = int(len(shuffled_df)*0.8)

train_df = shuffled_df[:train_len]
valid_df = shuffled_df[train_len:]

train_img_path = train_df['img_path'].to_list()
train_label = train_df['leaf_weight'].to_list()

valid_img_path = valid_df['img_path'].to_list()
valid_label = valid_df['leaf_weight'].to_list()

# %%
# %%time
train_img = np.array(list(map(cv2.imread, train_img_path)))
valid_img = np.array(list(map(cv2.imread, valid_img_path)))
# Out:
# CPU times: user 11.3 s, sys: 2.61 s, total: 13.9 s
# Wall time: 15.4 s

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                 rotation_range=10,
                                 shear_range=0.1,
                                 horizontal_flip=True,
                                 vertical_flip=True,
                                 fill_mode = 'nearest')
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
BATCH_SIZE = 19

train_generator = train_datagen.flow(train_img,
                                    train_label,
                                    batch_size=BATCH_SIZE)

valid_generator = test_datagen.flow(valid_img,
                                    valid_label,
                                   batch_size=BATCH_SIZE)

# %%
IMAGE_SIZE = 512
MODEL_IMAGE_SIZE = 299

# %% [markdown]
# # Definitions

# %%
def NMAE(y_true, y_pred) :
    error = y_true - y_pred
    absolute_error = tf.abs(error)
    return tf.reduce_mean(absolute_error) / tf.reduce_mean(y_true)

def nmae(y_true, y_pred):
    score = tf.py_function(func=NMAE, inp=[y_true, y_pred], Tout=tf.float32, name='nmae')
    return score

# %% [markdown]
# <h1> inception_v2_resnet 0.01 adam 0.2 </h1>
# <img src='./Training_Result/inception_v2_resnet 0.01 adam 0.2.png'/>

# %%
base_model = inception_resnet_v2.InceptionResNetV2(
            weights='imagenet',
            include_top = False,
            input_shape = (MODEL_IMAGE_SIZE, MODEL_IMAGE_SIZE,3))

input_data = Input((IMAGE_SIZE, IMAGE_SIZE, 3))
output_data = tf.keras.layers.experimental.preprocessing.Resizing(MODEL_IMAGE_SIZE, MODEL_IMAGE_SIZE)(input_data)
resizing = Model(inputs=input_data, outputs=output_data, name='resize')

# model
inputs = Input((IMAGE_SIZE, IMAGE_SIZE, 3))
x = resizing(inputs)
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
outputs = Dense(1, activation='relu')(x)
model = Model(inputs, outputs)

base_model.trainable = False
model.summary()
# Out:
# 2022-05-17 14:29:32.428954: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-05-17 14:29:32.485764: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-05-17 14:29:32.560058: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:32.562068: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-05-17 14:29:32.562465: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-17 14:29:32.652222: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-05-17 14:29:32.652281: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-05-17 14:29:32.700062: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-05-17 14:29:32.709235: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-05-17 14:29:32.792047: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-05-17 14:29:32.802433: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-05-17 14:29:32.940984: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-05-17 14:29:32.941113: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:32.941779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:32.943009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-05-17 14:29:32.945237: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-17 14:29:32.945991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:32.946569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-05-17 14:29:32.946594: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-17 14:29:32.946609: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-05-17 14:29:32.946620: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-05-17 14:29:32.946631: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-05-17 14:29:32.946641: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-05-17 14:29:32.946652: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-05-17 14:29:32.946662: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-05-17 14:29:32.946674: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-05-17 14:29:32.946725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:32.947292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:32.947819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-05-17 14:29:32.948637: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-17 14:29:34.671756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-05-17 14:29:34.671787: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-05-17 14:29:34.672367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-05-17 14:29:34.673360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:34.674004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:34.674579: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 14:29:34.675117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13970 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5)
# 2022-05-17 14:29:34.678021: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# resize (Functional)          (None, 299, 299, 3)       0
# _________________________________________________________________
# inception_resnet_v2 (Functio (None, 8, 8, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 55,911,649
# Trainable params: 1,574,913
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(0.01),
            loss='mae',
            metrics=[nmae])

es = EarlyStopping(monitor='loss',
                mode='auto',
                patience=5,
                verbose=1)

ckpt_path = './Best_Check_Point/best_params1_top_layers.ckpt'
checkpointer = ModelCheckpoint(filepath=ckpt_path,
                              monitor='val_nmae',
                              save_weights_only = True,
                              save_best_only= True,
                              verbose=1)

STEPS_PER_EPOCH = len(train_img) // BATCH_SIZE
VAL_STEPS = len(valid_img) // BATCH_SIZE

history = model.fit(train_generator, epochs=2000,
                  steps_per_epoch=STEPS_PER_EPOCH,
                  validation_data=valid_generator,
                  validation_steps = VAL_STEPS,
                  callbacks=[checkpointer, es],
                  verbose=1)
# Out:
# 2022-05-17 14:29:41.979305: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-05-17 14:29:42.001648: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/2000
# 2022-05-17 14:29:49.688851: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-05-17 14:29:50.587797: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 67/67 [==============================] - 79s 1s/step - loss: 36.1472 - nmae: 0.4553 - val_loss: 19.2146 - val_nmae: 0.2354
#
# Epoch 00001: val_nmae improved from inf to 0.23545, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 2/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 15.6074 - nmae: 0.1973 - val_loss: 14.7266 - val_nmae: 0.1769
#
# Epoch 00002: val_nmae improved from 0.23545 to 0.17689, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 3/2000
# 67/67 [==============================] - 66s 980ms/step - loss: 14.2599 - nmae: 0.1826 - val_loss: 17.1865 - val_nmae: 0.2266
#
# Epoch 00003: val_nmae did not improve from 0.17689
# Epoch 4/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 13.1329 - nmae: 0.1739 - val_loss: 14.6932 - val_nmae: 0.1749
#
# Epoch 00004: val_nmae improved from 0.17689 to 0.17490, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 5/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 13.5585 - nmae: 0.1790 - val_loss: 12.8179 - val_nmae: 0.1593
#
# Epoch 00005: val_nmae improved from 0.17490 to 0.15935, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 6/2000
# 67/67 [==============================] - 65s 972ms/step - loss: 13.5646 - nmae: 0.1698 - val_loss: 11.9016 - val_nmae: 0.1486
#
# Epoch 00006: val_nmae improved from 0.15935 to 0.14855, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 7/2000
# 67/67 [==============================] - 65s 971ms/step - loss: 11.5501 - nmae: 0.1425 - val_loss: 15.2053 - val_nmae: 0.1780
#
# Epoch 00007: val_nmae did not improve from 0.14855
# Epoch 8/2000
# 67/67 [==============================] - 65s 966ms/step - loss: 12.7508 - nmae: 0.1693 - val_loss: 12.2526 - val_nmae: 0.1426
#
# Epoch 00008: val_nmae improved from 0.14855 to 0.14264, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 9/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 17.7070 - nmae: 0.2184 - val_loss: 11.4209 - val_nmae: 0.1426
#
# Epoch 00009: val_nmae improved from 0.14264 to 0.14256, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 10/2000
# 67/67 [==============================] - 65s 974ms/step - loss: 11.9215 - nmae: 0.1545 - val_loss: 26.9800 - val_nmae: 0.3107
#
# Epoch 00010: val_nmae did not improve from 0.14256
# Epoch 11/2000
# 67/67 [==============================] - 66s 980ms/step - loss: 13.0294 - nmae: 0.1600 - val_loss: 10.4596 - val_nmae: 0.1255
#
# Epoch 00011: val_nmae improved from 0.14256 to 0.12552, saving model to ./Best_Check_Point/best_params1_top_layers.ckpt
# Epoch 12/2000
# 67/67 [==============================] - 65s 969ms/step - loss: 10.8153 - nmae: 0.1385 - val_loss: 14.1316 - val_nmae: 0.1779
#
# Epoch 00012: val_nmae did not improve from 0.12552
# Epoch 13/2000
# 67/67 [==============================] - 65s 974ms/step - loss: 10.2547 - nmae: 0.1314 - val_loss: 17.4154 - val_nmae: 0.1978
#
# Epoch 00013: val_nmae did not improve from 0.12552
# Epoch 14/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 12.7657 - nmae: 0.1650 - val_loss: 17.0529 - val_nmae: 0.2066
#
# Epoch 00014: val_nmae did not improve from 0.12552
# Epoch 15/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 12.9393 - nmae: 0.1706 - val_loss: 11.0010 - val_nmae: 0.1359
#
# Epoch 00015: val_nmae did not improve from 0.12552
# Epoch 16/2000
# 67/67 [==============================] - 65s 974ms/step - loss: 11.3803 - nmae: 0.1455 - val_loss: 11.4320 - val_nmae: 0.1345
#
# Epoch 00016: val_nmae did not improve from 0.12552
# Epoch 17/2000
# 67/67 [==============================] - 65s 976ms/step - loss: 10.1918 - nmae: 0.1294 - val_loss: 12.4699 - val_nmae: 0.1522
#
# Epoch 00017: val_nmae did not improve from 0.12552
# Epoch 18/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 10.6302 - nmae: 0.1344 - val_loss: 11.4285 - val_nmae: 0.1360
#
# Epoch 00018: val_nmae did not improve from 0.12552
# Epoch 19/2000
# 67/67 [==============================] - 66s 978ms/step - loss: 11.0604 - nmae: 0.1399 - val_loss: 12.2757 - val_nmae: 0.1429
#
# Epoch 00019: val_nmae did not improve from 0.12552
# Epoch 20/2000
# 67/67 [==============================] - 65s 974ms/step - loss: 10.2633 - nmae: 0.1272 - val_loss: 19.9651 - val_nmae: 0.2469
#
# Epoch 00020: val_nmae did not improve from 0.12552
# Epoch 21/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 11.7999 - nmae: 0.1614 - val_loss: 11.2284 - val_nmae: 0.1349
#
# Epoch 00021: val_nmae did not improve from 0.12552
# Epoch 22/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 9.4598 - nmae: 0.1239 - val_loss: 15.6346 - val_nmae: 0.1908
#
# Epoch 00022: val_nmae did not improve from 0.12552
# Epoch 23/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 12.5018 - nmae: 0.1635 - val_loss: 13.8008 - val_nmae: 0.1586
#
# Epoch 00023: val_nmae did not improve from 0.12552
# Epoch 00023: early stopping

# %%
model.save('./Model_Save/best1_top_layer.h5')

# %%
train_loss = history.history['loss']
valid_loss = history.history['val_loss']
train_nmae = history.history['nmae']
valid_nmae = history.history['val_nmae']

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(1,2,1)
ax1.plot(train_loss, label='Training Loss')
ax1.plot(valid_loss, label='Validation Loss')
ax1.legend(loc='upper right')
ax1.set_title('MAE : inception_v2_resnet 0.01 adam 0.2 : top layer')

ax2 = fig.add_subplot(1,2,2)
ax2.plot(train_nmae, label='Training NMAE')
ax2.plot(valid_nmae, label='Validation NMAE')
ax2.legend(loc='upper right')
ax2.set_title('NMAE : inception_v2_resnet 0.01 adam 0.2 : top layer')

plt.show()

# %% [markdown]
# ### finetune

# %%
history_dict = {}

# %%
for freeze_rate in [0.9, 0.7, 0.5, 0.3] :
    model.load_weights('./Best_Check_Point/best_params1_top_layers.ckpt')
    
    base_model.trainable=True
    fine_tune_at = int(len(base_model.layers) * freeze_rate)
    for layer in base_model.layers[:fine_tune_at] :
        layer.trainable = False    
        
    model.compile(optimizer=Adam(0.001),
            loss='mae',
            metrics=[nmae])

    es = EarlyStopping(monitor='loss',
                    mode='auto',
                    patience=5,
                    verbose=1)

    ckpt_path = './Best_Check_Point/best_params1_finetune_{}.ckpt'.format(freeze_rate)
    checkpointer = ModelCheckpoint(filepath=ckpt_path,
                                  monitor='val_nmae',
                                  save_weights_only = True,
                                  save_best_only= True,
                                  verbose=1)

    STEPS_PER_EPOCH = len(train_img) // BATCH_SIZE
    VAL_STEPS = len(valid_img) // BATCH_SIZE

    history_fine = model.fit(train_generator, epochs=2000,
                      steps_per_epoch=STEPS_PER_EPOCH,
                      validation_data=valid_generator,
                      validation_steps = VAL_STEPS,
                      callbacks=[checkpointer, es],
                      verbose=1)
    
    model.save('./Model_Save/best_params1_finetune_{}.h5'.format(freeze_rate))
    model.load_weights(ckpt_path)
    model.save('./Model_Save/best_params1_finetune_{}_2.h5'.format(freeze_rate))
    
    history_dict[str(freeze_rate)] = history_fine
    
    fig = plt.figure(figsize=(10,6))
    ax1 = fig.add_subplot(1,2,1)
    ax1.plot(train_loss + history_fine.history['loss'], label='Training Loss')
    ax1.plot(valid_loss + history_fine.history['val_loss'], label='Validation Loss')
    ax1.legend(loc='upper right')
    ax1.set_title('MAE : inception_v2_resnet 0.01 adam 0.2 finetune-{}'.format(freeze_rate))

    ax2 = fig.add_subplot(1,2,2)
    ax2.plot(train_nmae + history_fine.history['nmae'], label='Training NMAE')
    ax2.plot(valid_nmae + history_fine.history['val_nmae'], label='Validation NMAE')
    ax2.legend(loc='upper right')
    ax2.set_title('NMAE : inception_v2_resnet 0.01 adam 0.2 finetune-{}'.format(freeze_rate))
    
    plt.show()
# Out:
# Epoch 1/2000
# 67/67 [==============================] - 76s 1s/step - loss: 231.3031 - nmae: 3.6799 - val_loss: 16.2300 - val_nmae: 0.1924
#
# Epoch 00001: val_nmae improved from inf to 0.19238, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 2/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 17.5188 - nmae: 0.2323 - val_loss: 12.6547 - val_nmae: 0.1536
#
# Epoch 00002: val_nmae improved from 0.19238 to 0.15361, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 3/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 16.3782 - nmae: 0.2010 - val_loss: 10.6496 - val_nmae: 0.1322
#
# Epoch 00003: val_nmae improved from 0.15361 to 0.13220, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 4/2000
# 67/67 [==============================] - 66s 979ms/step - loss: 20.0623 - nmae: 0.2475 - val_loss: 19.3272 - val_nmae: 0.2338
#
# Epoch 00004: val_nmae did not improve from 0.13220
# Epoch 5/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 17.8314 - nmae: 0.2121 - val_loss: 13.6394 - val_nmae: 0.1646
#
# Epoch 00005: val_nmae did not improve from 0.13220
# Epoch 6/2000
# 67/67 [==============================] - 66s 979ms/step - loss: 14.3168 - nmae: 0.1779 - val_loss: 24.2706 - val_nmae: 0.2912
#
# Epoch 00006: val_nmae did not improve from 0.13220
# Epoch 7/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 12.5786 - nmae: 0.1592 - val_loss: 8.7963 - val_nmae: 0.1075
#
# Epoch 00007: val_nmae improved from 0.13220 to 0.10754, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 8/2000
# 67/67 [==============================] - 66s 974ms/step - loss: 11.1968 - nmae: 0.1470 - val_loss: 18.3891 - val_nmae: 0.2222
#
# Epoch 00008: val_nmae did not improve from 0.10754
# Epoch 9/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 12.9719 - nmae: 0.1613 - val_loss: 8.7146 - val_nmae: 0.1016
#
# Epoch 00009: val_nmae improved from 0.10754 to 0.10158, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 10/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 11.5389 - nmae: 0.1390 - val_loss: 16.0303 - val_nmae: 0.1893
#
# Epoch 00010: val_nmae did not improve from 0.10158
# Epoch 11/2000
# 67/67 [==============================] - 66s 982ms/step - loss: 16.2156 - nmae: 0.1857 - val_loss: 17.1837 - val_nmae: 0.2032
#
# Epoch 00011: val_nmae did not improve from 0.10158
# Epoch 12/2000
# 67/67 [==============================] - 66s 982ms/step - loss: 13.7513 - nmae: 0.1784 - val_loss: 9.7112 - val_nmae: 0.1153
#
# Epoch 00012: val_nmae did not improve from 0.10158
# Epoch 13/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 11.1572 - nmae: 0.1395 - val_loss: 8.3421 - val_nmae: 0.1005
#
# Epoch 00013: val_nmae improved from 0.10158 to 0.10051, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 14/2000
# 67/67 [==============================] - 66s 975ms/step - loss: 9.4451 - nmae: 0.1200 - val_loss: 8.4176 - val_nmae: 0.0998
#
# Epoch 00014: val_nmae improved from 0.10051 to 0.09984, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 15/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 9.4532 - nmae: 0.1273 - val_loss: 7.8129 - val_nmae: 0.0909
#
# Epoch 00015: val_nmae improved from 0.09984 to 0.09095, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 16/2000
# 67/67 [==============================] - 66s 980ms/step - loss: 9.4547 - nmae: 0.1130 - val_loss: 7.6005 - val_nmae: 0.0925
#
# Epoch 00016: val_nmae did not improve from 0.09095
# Epoch 17/2000
# 67/67 [==============================] - 66s 979ms/step - loss: 10.8823 - nmae: 0.1349 - val_loss: 9.4674 - val_nmae: 0.1130
#
# Epoch 00017: val_nmae did not improve from 0.09095
# Epoch 18/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 8.1106 - nmae: 0.1041 - val_loss: 7.1462 - val_nmae: 0.0864
#
# Epoch 00018: val_nmae improved from 0.09095 to 0.08641, saving model to ./Best_Check_Point/best_params1_finetune_0.9.ckpt
# Epoch 19/2000
# 67/67 [==============================] - 66s 978ms/step - loss: 8.2453 - nmae: 0.1085 - val_loss: 7.3532 - val_nmae: 0.0900
#
# Epoch 00019: val_nmae did not improve from 0.08641
# Epoch 20/2000
# 67/67 [==============================] - 66s 978ms/step - loss: 8.5160 - nmae: 0.1149 - val_loss: 11.2696 - val_nmae: 0.1391
#
# Epoch 00020: val_nmae did not improve from 0.08641
# Epoch 21/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 10.2067 - nmae: 0.1314 - val_loss: 8.1783 - val_nmae: 0.1009
#
# Epoch 00021: val_nmae did not improve from 0.08641
# Epoch 22/2000
# 67/67 [==============================] - 65s 974ms/step - loss: 10.8301 - nmae: 0.1467 - val_loss: 9.0007 - val_nmae: 0.1042
#
# Epoch 00022: val_nmae did not improve from 0.08641
# Epoch 23/2000
# 67/67 [==============================] - 66s 981ms/step - loss: 12.6939 - nmae: 0.1616 - val_loss: 7.3368 - val_nmae: 0.0895
#
# Epoch 00023: val_nmae did not improve from 0.08641
# Epoch 00023: early stopping
# Epoch 1/2000
# 67/67 [==============================] - 78s 1s/step - loss: 934.8070 - nmae: 9.6820 - val_loss: 83.9411 - val_nmae: 0.9839
#
# Epoch 00001: val_nmae improved from inf to 0.98387, saving model to ./Best_Check_Point/best_params1_finetune_0.7.ckpt
# Epoch 2/2000
# 67/67 [==============================] - 66s 983ms/step - loss: 78.8818 - nmae: 0.9913 - val_loss: 57.7569 - val_nmae: 0.6936
#
# Epoch 00002: val_nmae improved from 0.98387 to 0.69357, saving model to ./Best_Check_Point/best_params1_finetune_0.7.ckpt
# Epoch 3/2000
# 67/67 [==============================] - 66s 984ms/step - loss: 64.4702 - nmae: 0.8437 - val_loss: 84.1463 - val_nmae: 0.9945
#
# Epoch 00003: val_nmae did not improve from 0.69357
# Epoch 4/2000
# 67/67 [==============================] - 66s 984ms/step - loss: 76.2498 - nmae: 0.9862 - val_loss: 85.0526 - val_nmae: 0.9935
#
# Epoch 00004: val_nmae did not improve from 0.69357
# Epoch 5/2000
# 67/67 [==============================] - 66s 987ms/step - loss: 77.1728 - nmae: 1.0035 - val_loss: 83.3124 - val_nmae: 1.0000
#
# Epoch 00005: val_nmae did not improve from 0.69357
# Epoch 6/2000
# 67/67 [==============================] - 66s 986ms/step - loss: 74.0092 - nmae: 0.9994 - val_loss: 86.3585 - val_nmae: 1.0000
#
# Epoch 00006: val_nmae did not improve from 0.69357
# Epoch 7/2000
# 67/67 [==============================] - 67s 990ms/step - loss: 1296.5375 - nmae: 28.9906 - val_loss: 85.0016 - val_nmae: 1.0000
#
# Epoch 00007: val_nmae did not improve from 0.69357
# Epoch 8/2000
# 67/67 [==============================] - 66s 986ms/step - loss: 84.8694 - nmae: 1.0000 - val_loss: 85.7384 - val_nmae: 1.0000
#
# Epoch 00008: val_nmae did not improve from 0.69357
# Epoch 00008: early stopping
# Epoch 1/2000
# 67/67 [==============================] - 79s 1s/step - loss: 216.3431 - nmae: 2.5655 - val_loss: 83.6147 - val_nmae: 1.0000
#
# Epoch 00001: val_nmae improved from inf to 1.00000, saving model to ./Best_Check_Point/best_params1_finetune_0.5.ckpt
# Epoch 2/2000
# 67/67 [==============================] - 66s 986ms/step - loss: 78.7906 - nmae: 1.0000 - val_loss: 84.2922 - val_nmae: 1.0000
#
# Epoch 00002: val_nmae did not improve from 1.00000
# Epoch 3/2000
# 67/67 [==============================] - 66s 984ms/step - loss: 78.1245 - nmae: 1.0000 - val_loss: 84.3750 - val_nmae: 1.0000
#
# Epoch 00003: val_nmae did not improve from 1.00000
# Epoch 4/2000
# 67/67 [==============================] - 67s 1s/step - loss: 80.8178 - nmae: 1.0000 - val_loss: 86.0423 - val_nmae: 1.0000
#
# Epoch 00004: val_nmae did not improve from 1.00000
# Epoch 5/2000
# 67/67 [==============================] - 66s 987ms/step - loss: 79.2745 - nmae: 1.0000 - val_loss: 83.5477 - val_nmae: 1.0000
#
# Epoch 00005: val_nmae did not improve from 1.00000
# Epoch 6/2000
# 67/67 [==============================] - 66s 986ms/step - loss: 76.4578 - nmae: 1.0000 - val_loss: 84.0141 - val_nmae: 1.0000
#
# Epoch 00006: val_nmae did not improve from 1.00000
# Epoch 7/2000
# 67/67 [==============================] - 66s 987ms/step - loss: 79.2220 - nmae: 1.0000 - val_loss: 83.7418 - val_nmae: 1.0000
#
# Epoch 00007: val_nmae did not improve from 1.00000
# Epoch 8/2000
# 67/67 [==============================] - 66s 986ms/step - loss: 81.8454 - nmae: 1.0000 - val_loss: 83.0796 - val_nmae: 1.0000
#
# Epoch 00008: val_nmae did not improve from 1.00000
# Epoch 9/2000
# 67/67 [==============================] - 66s 981ms/step - loss: 81.4006 - nmae: 1.0000 - val_loss: 85.8801 - val_nmae: 1.0000
#
# Epoch 00009: val_nmae did not improve from 1.00000
# Epoch 10/2000
# 67/67 [==============================] - 67s 991ms/step - loss: 79.3743 - nmae: 1.0000 - val_loss: 83.3592 - val_nmae: 1.0000
#
# Epoch 00010: val_nmae did not improve from 1.00000
# Epoch 00010: early stopping
# Epoch 1/2000
# 67/67 [==============================] - 82s 1s/step - loss: 24179.9328 - nmae: 236.4196 - val_loss: 94.5878 - val_nmae: 1.2112
#
# Epoch 00001: val_nmae improved from inf to 1.21116, saving model to ./Best_Check_Point/best_params1_finetune_0.3.ckpt
# Epoch 2/2000
# 67/67 [==============================] - 66s 985ms/step - loss: 104.9681 - nmae: 1.4989 - val_loss: 85.4963 - val_nmae: 1.0000
#
# Epoch 00002: val_nmae improved from 1.21116 to 1.00000, saving model to ./Best_Check_Point/best_params1_finetune_0.3.ckpt
# Epoch 3/2000
# 67/67 [==============================] - 66s 985ms/step - loss: 77.6283 - nmae: 1.0000 - val_loss: 84.8209 - val_nmae: 1.0000
#
# Epoch 00003: val_nmae did not improve from 1.00000
# Epoch 4/2000
# 67/67 [==============================] - 67s 987ms/step - loss: 79.7925 - nmae: 0.9999 - val_loss: 84.7748 - val_nmae: 1.0000
#
# Epoch 00004: val_nmae did not improve from 1.00000
# Epoch 5/2000
# 67/67 [==============================] - 66s 985ms/step - loss: 79.1467 - nmae: 0.9999 - val_loss: 85.3970 - val_nmae: 1.0000
#
# Epoch 00005: val_nmae did not improve from 1.00000
# Epoch 6/2000
# 67/67 [==============================] - 67s 990ms/step - loss: 78.8026 - nmae: 0.9999 - val_loss: 83.7372 - val_nmae: 1.0000
#
# Epoch 00006: val_nmae did not improve from 1.00000
# Epoch 7/2000
# 67/67 [==============================] - 69s 1s/step - loss: 77.8626 - nmae: 0.9999 - val_loss: 84.9497 - val_nmae: 1.0000
#
# Epoch 00007: val_nmae did not improve from 1.00000
# Epoch 8/2000
# 67/67 [==============================] - 67s 990ms/step - loss: 71.8933 - nmae: 0.9998 - val_loss: 84.7560 - val_nmae: 1.0000
#
# Epoch 00008: val_nmae did not improve from 1.00000
# Epoch 9/2000
# 67/67 [==============================] - 66s 986ms/step - loss: 79.8706 - nmae: 0.9999 - val_loss: 82.5418 - val_nmae: 1.0000
#
# Epoch 00009: val_nmae did not improve from 1.00000
# Epoch 10/2000
# 67/67 [==============================] - 67s 987ms/step - loss: 80.6590 - nmae: 0.9999 - val_loss: 86.0387 - val_nmae: 1.0000
#
# Epoch 00010: val_nmae did not improve from 1.00000
# Epoch 11/2000
# 67/67 [==============================] - 67s 987ms/step - loss: 78.8807 - nmae: 0.9998 - val_loss: 83.5333 - val_nmae: 1.0000
#
# Epoch 00011: val_nmae did not improve from 1.00000
# Epoch 12/2000
# 67/67 [==============================] - 67s 990ms/step - loss: 86.7416 - nmae: 0.9999 - val_loss: 83.1126 - val_nmae: 1.0000
#
# Epoch 00012: val_nmae did not improve from 1.00000
# Epoch 13/2000
# 67/67 [==============================] - 66s 984ms/step - loss: 80.4341 - nmae: 0.9999 - val_loss: 82.9195 - val_nmae: 1.0000
#
# Epoch 00013: val_nmae did not improve from 1.00000
# Epoch 14/2000
# 67/67 [==============================] - 66s 985ms/step - loss: 79.1857 - nmae: 0.9999 - val_loss: 84.3562 - val_nmae: 1.0000
#
# Epoch 00014: val_nmae did not improve from 1.00000
# Epoch 15/2000
# 67/67 [==============================] - 66s 982ms/step - loss: 76.7348 - nmae: 0.9999 - val_loss: 83.2787 - val_nmae: 1.0000
#
# Epoch 00015: val_nmae did not improve from 1.00000
# Epoch 16/2000
# 67/67 [==============================] - 66s 985ms/step - loss: 79.1166 - nmae: 0.9998 - val_loss: 82.8126 - val_nmae: 1.0000
#
# Epoch 00016: val_nmae did not improve from 1.00000
# Epoch 17/2000
# 67/67 [==============================] - 66s 985ms/step - loss: 80.9837 - nmae: 0.9999 - val_loss: 84.5550 - val_nmae: 1.0000
#
# Epoch 00017: val_nmae did not improve from 1.00000
# Epoch 18/2000
# 67/67 [==============================] - 67s 987ms/step - loss: 80.7131 - nmae: 0.9999 - val_loss: 83.0706 - val_nmae: 1.0000
#
# Epoch 00018: val_nmae did not improve from 1.00000
# Epoch 19/2000
# 67/67 [==============================] - 67s 988ms/step - loss: 83.9381 - nmae: 0.9999 - val_loss: 85.6384 - val_nmae: 1.0000
#
# Epoch 00019: val_nmae did not improve from 1.00000
# Epoch 20/2000
# 67/67 [==============================] - 67s 988ms/step - loss: 83.6778 - nmae: 0.9998 - val_loss: 82.2291 - val_nmae: 1.0000
#
# Epoch 00020: val_nmae did not improve from 1.00000
# Epoch 21/2000
# 67/67 [==============================] - 67s 989ms/step - loss: 76.9022 - nmae: 0.9998 - val_loss: 84.2188 - val_nmae: 1.0000
#
# Epoch 00021: val_nmae did not improve from 1.00000
# Epoch 00021: early stopping

# %% [markdown]
# <h1> inception_v2_resnet 0.001 adam 0.2 </h1>
# <img src='./Training_Result/inception_v2_resnet 0.001 adam 0.2.png'/>

# %%
tf.keras.backend.clear_session()

base_model = inception_resnet_v2.InceptionResNetV2(
            weights='imagenet',
            include_top = False,
            input_shape = (MODEL_IMAGE_SIZE, MODEL_IMAGE_SIZE,3))

input_data = Input((IMAGE_SIZE, IMAGE_SIZE, 3))
output_data = tf.keras.layers.experimental.preprocessing.Resizing(MODEL_IMAGE_SIZE, MODEL_IMAGE_SIZE)(input_data)
resizing = Model(inputs=input_data, outputs=output_data, name='resize')

# model
inputs = Input((IMAGE_SIZE, IMAGE_SIZE, 3))
x = resizing(inputs)
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
outputs = Dense(1, activation='relu')(x)
model = Model(inputs, outputs)

base_model.trainable = False
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# resize (Functional)          (None, 299, 299, 3)       0
# _________________________________________________________________
# inception_resnet_v2 (Functio (None, 8, 8, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 55,911,649
# Trainable params: 1,574,913
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(0.001),
            loss='mae',
            metrics=[nmae])

es = EarlyStopping(monitor='loss',
                mode='auto',
                patience=5,
                verbose=1)

ckpt_path = './Best_Check_Point/best_params2_top_layers.ckpt'
checkpointer = ModelCheckpoint(filepath=ckpt_path,
                              monitor='val_nmae',
                              save_weights_only = True,
                              save_best_only= True,
                              verbose=1)

STEPS_PER_EPOCH = len(train_img) // BATCH_SIZE
VAL_STEPS = len(valid_img) // BATCH_SIZE

history = model.fit(train_generator, epochs=2000,
                  steps_per_epoch=STEPS_PER_EPOCH,
                  validation_data=valid_generator,
                  validation_steps = VAL_STEPS,
                  callbacks=[checkpointer, es],
                  verbose=1)

model.save('./best2_top_layer.h5')
# Out:
# Epoch 1/2000
# 67/67 [==============================] - 76s 1s/step - loss: 49.3046 - nmae: 0.6622 - val_loss: 17.7064 - val_nmae: 0.2246
#
# Epoch 00001: val_nmae improved from inf to 0.22463, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 2/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 18.5583 - nmae: 0.2330 - val_loss: 16.0626 - val_nmae: 0.1896
#
# Epoch 00002: val_nmae improved from 0.22463 to 0.18961, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 3/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 15.9873 - nmae: 0.1949 - val_loss: 15.6835 - val_nmae: 0.1858
#
# Epoch 00003: val_nmae improved from 0.18961 to 0.18580, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 4/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 15.7078 - nmae: 0.2023 - val_loss: 15.2492 - val_nmae: 0.1820
#
# Epoch 00004: val_nmae improved from 0.18580 to 0.18200, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 5/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 14.0614 - nmae: 0.1891 - val_loss: 13.6535 - val_nmae: 0.1686
#
# Epoch 00005: val_nmae improved from 0.18200 to 0.16856, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 6/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 13.6979 - nmae: 0.1739 - val_loss: 15.6799 - val_nmae: 0.1964
#
# Epoch 00006: val_nmae did not improve from 0.16856
# Epoch 7/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 13.1737 - nmae: 0.1683 - val_loss: 15.5467 - val_nmae: 0.1908
#
# Epoch 00007: val_nmae did not improve from 0.16856
# Epoch 8/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 13.0262 - nmae: 0.1698 - val_loss: 12.6839 - val_nmae: 0.1543
#
# Epoch 00008: val_nmae improved from 0.16856 to 0.15430, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 9/2000
# 67/67 [==============================] - 65s 974ms/step - loss: 13.6215 - nmae: 0.1835 - val_loss: 12.6186 - val_nmae: 0.1562
#
# Epoch 00009: val_nmae did not improve from 0.15430
# Epoch 10/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 12.9818 - nmae: 0.1585 - val_loss: 14.7666 - val_nmae: 0.1747
#
# Epoch 00010: val_nmae did not improve from 0.15430
# Epoch 11/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 13.5668 - nmae: 0.1757 - val_loss: 15.9329 - val_nmae: 0.2011
#
# Epoch 00011: val_nmae did not improve from 0.15430
# Epoch 12/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 13.5050 - nmae: 0.1737 - val_loss: 12.1583 - val_nmae: 0.1480
#
# Epoch 00012: val_nmae improved from 0.15430 to 0.14802, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 13/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 12.9014 - nmae: 0.1747 - val_loss: 12.9110 - val_nmae: 0.1634
#
# Epoch 00013: val_nmae did not improve from 0.14802
# Epoch 14/2000
# 67/67 [==============================] - 65s 975ms/step - loss: 11.2804 - nmae: 0.1497 - val_loss: 12.1103 - val_nmae: 0.1495
#
# Epoch 00014: val_nmae did not improve from 0.14802
# Epoch 15/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 11.0923 - nmae: 0.1464 - val_loss: 15.7364 - val_nmae: 0.1992
#
# Epoch 00015: val_nmae did not improve from 0.14802
# Epoch 16/2000
# 67/67 [==============================] - 66s 977ms/step - loss: 13.9431 - nmae: 0.1733 - val_loss: 11.6451 - val_nmae: 0.1400
#
# Epoch 00016: val_nmae improved from 0.14802 to 0.14003, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 17/2000
# 67/67 [==============================] - 65s 973ms/step - loss: 11.2402 - nmae: 0.1497 - val_loss: 11.1528 - val_nmae: 0.1360
#
# Epoch 00017: val_nmae improved from 0.14003 to 0.13603, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 18/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 12.0245 - nmae: 0.1547 - val_loss: 11.1800 - val_nmae: 0.1337
#
# Epoch 00018: val_nmae improved from 0.13603 to 0.13373, saving model to ./Best_Check_Point/best_params2_top_layers.ckpt
# Epoch 19/2000
# 67/67 [==============================] - 66s 976ms/step - loss: 11.3387 - nmae: 0.1498 - val_loss: 12.2161 - val_nmae: 0.1437
#
# Epoch 00019: val_nmae did not improve from 0.13373
# Epoch 00019: early stopping

# %%
train_loss = history.history['loss']
valid_loss = history.history['val_loss']
train_nmae = history.history['nmae']
valid_nmae = history.history['val_nmae']

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(1,2,1)
ax1.plot(train_loss, label='Training Loss')
ax1.plot(valid_loss, label='Validation Loss')
ax1.legend(loc='upper right')
ax1.set_title('MAE : inception_v2_resnet 0.001 adam 0.2 : top layer')

ax2 = fig.add_subplot(1,2,2)
ax2.plot(train_nmae, label='Training NMAE')
ax2.plot(valid_nmae, label='Validation NMAE')
ax2.legend(loc='upper right')
ax2.set_title('NMAE : inception_v2_resnet 0.001 adam 0.2 : top layer')

plt.show()

# %% [markdown]
# ### finetune

# %%
history_dict2 = {}

# %%
for freeze_rate in [0.9, 0.7, 0.5, 0.3] :
    model.load_weights('./Best_Check_Point/best_params2_top_layers.ckpt')
    
    base_model.trainable=True
    fine_tune_at = int(len(base_model.layers) * freeze_rate)
    for layer in base_model.layers[:fine_tune_at] :
        layer.trainable = False    
        
    model.compile(optimizer=Adam(0.0001),
            loss='mae',
            metrics=[nmae])

    es = EarlyStopping(monitor='loss',
                    mode='auto',
                    patience=5,
                    verbose=1)

    ckpt_path = './Best_Check_Point/best_params2_finetune_{}.ckpt'.format(freeze_rate)
    checkpointer = ModelCheckpoint(filepath=ckpt_path,
                                  monitor='val_nmae',
                                  save_weights_only = True,
                                  save_best_only= True,
                                  verbose=1)

    STEPS_PER_EPOCH = len(train_img) // BATCH_SIZE
    VAL_STEPS = len(valid_img) // BATCH_SIZE

    history_fine = model.fit(train_generator, epochs=2000,
                      steps_per_epoch=STEPS_PER_EPOCH,
                      validation_data=valid_generator,
                      validation_steps = VAL_STEPS,
                      callbacks=[checkpointer, es],
                      verbose=1)
                             
    model.save('./Model_Save/best_params2_finetune_{}.h5'.format(freeze_rate))
    model.load_weights(ckpt_path)
    model.save('./Model_Save/best_params2_finetune_{}_2.h5'.format(freeze_rate))
    
    history_dict2[str(freeze_rate)] = history_fine
    
    fig = plt.figure(figsize=(10,6))
    ax1 = fig.add_subplot(1,2,1)
    ax1.plot(train_loss + history_fine.history['loss'], label='Training Loss')
    ax1.plot(valid_loss + history_fine.history['val_loss'], label='Validation Loss')
    ax1.legend(loc='upper right')
    ax1.set_title('MAE : inception_v2_resnet 0.01 adam 0.2 finetune-{}'.format(freeze_rate))

    ax2 = fig.add_subplot(1,2,2)
    ax2.plot(train_nmae + history_fine.history['nmae'], label='Training NMAE')
    ax2.plot(valid_nmae + history_fine.history['val_nmae'], label='Validation NMAE')
    ax2.legend(loc='upper right')
    ax2.set_title('NMAE : inception_v2_resnet 0.01 adam 0.2 finetune-{}'.format(freeze_rate))
    
    plt.show()
# Out:
# Epoch 1/2000
# 67/67 [==============================] - 77s 1s/step - loss: 16.2273 - nmae: 0.1960 - val_loss: 14.9480 - val_nmae: 0.2007
#
# Epoch 00001: val_nmae improved from inf to 0.20068, saving model to ./Best_Check_Point/best_params2_finetune_0.9.ckpt
# Epoch 2/2000
# 67/67 [==============================] - 68s 1s/step - loss: 11.7200 - nmae: 0.1577 - val_loss: 8.1477 - val_nmae: 0.0972
#
# Epoch 00002: val_nmae improved from 0.20068 to 0.09716, saving model to ./Best_Check_Point/best_params2_finetune_0.9.ckpt
# Epoch 3/2000
# 67/67 [==============================] - 67s 1s/step - loss: 8.1970 - nmae: 0.1091 - val_loss: 8.1985 - val_nmae: 0.0952
#
# Epoch 00003: val_nmae improved from 0.09716 to 0.09518, saving model to ./Best_Check_Point/best_params2_finetune_0.9.ckpt
# Epoch 4/2000
# 67/67 [==============================] - 67s 994ms/step - loss: 9.1687 - nmae: 0.1152 - val_loss: 9.3730 - val_nmae: 0.1151
#
# Epoch 00004: val_nmae did not improve from 0.09518
# Epoch 5/2000
# 67/67 [==============================] - 67s 994ms/step - loss: 7.6989 - nmae: 0.1006 - val_loss: 9.2352 - val_nmae: 0.1158
#
# Epoch 00005: val_nmae did not improve from 0.09518
# Epoch 6/2000
# 67/67 [==============================] - 67s 996ms/step - loss: 7.4049 - nmae: 0.0927 - val_loss: 8.1988 - val_nmae: 0.1012
#
# Epoch 00006: val_nmae did not improve from 0.09518
# Epoch 7/2000
# 67/67 [==============================] - 66s 989ms/step - loss: 7.4964 - nmae: 0.0989 - val_loss: 12.2837 - val_nmae: 0.1528
#
# Epoch 00007: val_nmae did not improve from 0.09518
# Epoch 8/2000
# 67/67 [==============================] - 66s 989ms/step - loss: 6.9610 - nmae: 0.0868 - val_loss: 9.7766 - val_nmae: 0.1153
#
# Epoch 00008: val_nmae did not improve from 0.09518
# Epoch 9/2000
# 67/67 [==============================] - 66s 987ms/step - loss: 7.4447 - nmae: 0.0945 - val_loss: 7.4822 - val_nmae: 0.0877
#
# Epoch 00009: val_nmae improved from 0.09518 to 0.08767, saving model to ./Best_Check_Point/best_params2_finetune_0.9.ckpt
# Epoch 10/2000
# 67/67 [==============================] - 67s 990ms/step - loss: 7.4901 - nmae: 0.0959 - val_loss: 7.1904 - val_nmae: 0.0866
#
# Epoch 00010: val_nmae improved from 0.08767 to 0.08658, saving model to ./Best_Check_Point/best_params2_finetune_0.9.ckpt
# Epoch 11/2000
# 67/67 [==============================] - 66s 987ms/step - loss: 6.0569 - nmae: 0.0772 - val_loss: 5.8789 - val_nmae: 0.0707
#
# Epoch 00011: val_nmae improved from 0.08658 to 0.07067, saving model to ./Best_Check_Point/best_params2_finetune_0.9.ckpt
# Epoch 12/2000
# 67/67 [==============================] - 66s 986ms/step - loss: 5.9249 - nmae: 0.0693 - val_loss: 6.5452 - val_nmae: 0.0756
#
# Epoch 00012: val_nmae did not improve from 0.07067
# Epoch 13/2000
# 67/67 [==============================] - 66s 989ms/step - loss: 6.2338 - nmae: 0.0760 - val_loss: 8.0608 - val_nmae: 0.0945
#
# Epoch 00013: val_nmae did not improve from 0.07067
# Epoch 14/2000
# 67/67 [==============================] - 66s 990ms/step - loss: 6.3076 - nmae: 0.0778 - val_loss: 7.3525 - val_nmae: 0.0835
#
# Epoch 00014: val_nmae did not improve from 0.07067
# Epoch 15/2000
# 67/67 [==============================] - 66s 987ms/step - loss: 6.0460 - nmae: 0.0769 - val_loss: 8.0067 - val_nmae: 0.0946
#
# Epoch 00015: val_nmae did not improve from 0.07067
# Epoch 16/2000
# 67/67 [==============================] - 66s 988ms/step - loss: 4.8289 - nmae: 0.0690 - val_loss: 7.8901 - val_nmae: 0.0943
#
# Epoch 00016: val_nmae did not improve from 0.07067
# Epoch 17/2000
# 67/67 [==============================] - 66s 987ms/step - loss: 5.8763 - nmae: 0.0765 - val_loss: 6.2597 - val_nmae: 0.0760
#
# Epoch 00017: val_nmae did not improve from 0.07067
# Epoch 00017: early stopping
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
#      36 model.load_weights(ckpt_path)
#      37 model.save('./Model_Save/best_params2_finetune_{}_2.h5'.format(freeze_rate))
# ---> 39 history_dict2[str(freeze_rate)] = history_fine
#      41 fig = plt.figure(figsize=(10,6))
#      42 ax1 = fig.add_subplot(1,2,1)
#
# NameError: name 'history_dict2' is not defined
